# %%
# notebooks use their location as their working directory, so
# if we are in a subfolder, move to the main folder.  
# This however can safely be run multiple times
#setwd("M:/lecospec/lecospec")
if(!dir.exists("Functions/")){
    setwd("../")
    if(!dir.exists("Functions")){
        setwd("M:/lecospec/lecospec/")
    }
}
source("Functions/lecospectR.R", echo = FALSE)
library(class)
library(caret)
library(vegan)
# Out:
# Loading required package: tidyverse
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: compiler
#
# Loading required package: raster
#
# Loading required package: sp
#
#
# Attaching package: ‘raster’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# Loading required package: hsdar
#
# Loading required package: rgdal
#
# Please note that rgdal will be retired by the end of 2023,
# plan transition to sf/stars/terra functions using GDAL and PROJ
# at your earliest convenience.
#
# rgdal: version: 1.5-32, (SVN revision 1176)
# Geospatial Data Abstraction Library extensions to R successfully loaded
# Loaded GDAL runtime: GDAL 3.4.1, released 2021/12/27
# Path to GDAL shared files: /usr/share/gdal
# GDAL binary built with GEOS: TRUE
# Loaded PROJ runtime: Rel. 8.2.1, January 1st, 2022, [PJ_VERSION: 821]
# Path to PROJ shared files: /home/krbundy/.local/share/proj:/usr/share/proj
# PROJ CDN enabled: FALSE
# Linking to sp version:1.5-0
# To mute warnings of possible GDAL/OSR exportToProj4() degradation,
# use options("rgdal_show_exportToProj4_warnings"="none") before loading sp or rgdal.
#
# Loading required package: signal
#
#
# Attaching package: ‘signal’
#
#
# The following object is masked from ‘package:raster’:
#
#     resample
#
#
# The following object is masked from ‘package:dplyr’:
#
#     filter
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, poly
#
#
# Loading required package: caret
#
# Loading required package: lattice
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:purrr’:
#
#     lift
#
#
# Loading required package: Boruta
#
#
# ###################################
#   This is hsdar 1.0.4
#   To get citation entry type
#       'citation("hsdar")'
# ###################################
#
#
# Attaching package: ‘hsdar’
#
#
# The following object is masked from ‘package:raster’:
#
#     nbands
#
#
# Loading required package: spectrolab
#
# spectrolab version: 0.0.17
#
# Please cite:
# Meireles J, Schweiger A, Cavender-Bares J (2017). spectrolab: Class
# and Methods for Spectral Data in R. doi:10.5281/zenodo.3934575
# <https://doi.org/10.5281/zenodo.3934575>, R package version 0.0.17,
# <https://CRAN.R-project.org/package=spectrolab>.DOI: https://doi.org/10.5281/zenodo.3934575
#
#
# Attaching package: ‘spectrolab’
#
#
# The following object is masked from ‘package:hsdar’:
#
#     spectra
#
#
# The following object is masked from ‘package:signal’:
#
#     resample
#
#
# The following object is masked from ‘package:raster’:
#
#     resample
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# The following objects are masked from ‘package:stats’:
#
#     sd, smooth, var
#
#
# Loading required package: ranger
#
# Loading required package: stringi
#
# Loading required package: rjson
#
# Loading required package: snow
#
# Loading required package: doSNOW
#
# Loading required package: foreach
#
#
# Attaching package: ‘foreach’
#
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
#
# Loading required package: iterators
#
# Loading required package: rasterVis
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:signal’:
#
#     filter
#
#
# The following object is masked from ‘package:raster’:
#
#     select
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout
#
#
# Loading required package: permute
#
# This is vegan 2.6-4
#
#
# Attaching package: ‘vegan’
#
#
# The following object is masked from ‘package:caret’:
#
#     tolerance

# %% [markdown]
# ## Load the Data

# %%
# spectral library
base_path <- "./Output/C_001_SC3_Cleaned_SpectralLib.csv"
veg_index_path <- "./Data/D_002_SpecLib_Derivs.csv"
speclib <- read.csv(base_path)
veg_indices <- read.csv(veg_index_path)

# %%
colnames(speclib)[12:2162]
# Out:
#    [1] "X350"  "X351"  "X352"  "X353"  "X354"  "X355"  "X356"  "X357"  "X358"
#   [10] "X359"  "X360"  "X361"  "X362"  "X363"  "X364"  "X365"  "X366"  "X367"
#   [19] "X368"  "X369"  "X370"  "X371"  "X372"  "X373"  "X374"  "X375"  "X376"
#   [28] "X377"  "X378"  "X379"  "X380"  "X381"  "X382"  "X383"  "X384"  "X385"
#   [37] "X386"  "X387"  "X388"  "X389"  "X390"  "X391"  "X392"  "X393"  "X394"
#   [46] "X395"  "X396"  "X397"  "X398"  "X399"  "X400"  "X401"  "X402"  "X403"
#   [55] "X404"  "X405"  "X406"  "X407"  "X408"  "X409"  "X410"  "X411"  "X412"
#   [64] "X413"  "X414"  "X415"  "X416"  "X417"  "X418"  "X419"  "X420"  "X421"
#   [73] "X422"  "X423"  "X424"  "X425"  "X426"  "X427"  "X428"  "X429"  "X430"
#   [82] "X431"  "X432"  "X433"  "X434"  "X435"  "X436"  "X437"  "X438"  "X439"
#   [91] "X440"  "X441"  "X442"  "X443"  "X444"  "X445"  "X446"  "X447"  "X448"
#  [100] "X449"  "X450"  "X451"  "X452"  "X453"  "X454"  "X455"  "X456"  "X457"
#  [109] "X458"  "X459"  "X460"  "X461"  "X462"  "X463"  "X464"  "X465"  "X466"
#  [118] "X467"  "X468"  "X469"  "X470"  "X471"  "X472"  "X473"  "X474"  "X475"
#  [127] "X476"  "X477"  "X478"  "X479"  "X480"  "X481"  "X482"  "X483"  "X484"
#  [136] "X485"  "X486"  "X487"  "X488"  "X489"  "X490"  "X491"  "X492"  "X493"
#  [145] "X494"  "X495"  "X496"  "X497"  "X498"  "X499"  "X500"  "X501"  "X502"
#  [154] "X503"  "X504"  "X505"  "X506"  "X507"  "X508"  "X509"  "X510"  "X511"
#  [163] "X512"  "X513"  "X514"  "X515"  "X516"  "X517"  "X518"  "X519"  "X520"
#  [172] "X521"  "X522"  "X523"  "X524"  "X525"  "X526"  "X527"  "X528"  "X529"
#  [181] "X530"  "X531"  "X532"  "X533"  "X534"  "X535"  "X536"  "X537"  "X538"
#  [190] "X539"  "X540"  "X541"  "X542"  "X543"  "X544"  "X545"  "X546"  "X547"
#  [199] "X548"  "X549"  "X550"  "X551"  "X552"  "X553"  "X554"  "X555"  "X556"
#  [208] "X557"  "X558"  "X559"  "X560"  "X561"  "X562"  "X563"  "X564"  "X565"
#  [217] "X566"  "X567"  "X568"  "X569"  "X570"  "X571"  "X572"  "X573"  "X574"
#  [226] "X575"  "X576"  "X577"  "X578"  "X579"  "X580"  "X581"  "X582"  "X583"
#  [235] "X584"  "X585"  "X586"  "X587"  "X588"  "X589"  "X590"  "X591"  "X592"
#  [244] "X593"  "X594"  "X595"  "X596"  "X597"  "X598"  "X599"  "X600"  "X601"
#  [253] "X602"  "X603"  "X604"  "X605"  "X606"  "X607"  "X608"  "X609"  "X610"
#  [262] "X611"  "X612"  "X613"  "X614"  "X615"  "X616"  "X617"  "X618"  "X619"
#  [271] "X620"  "X621"  "X622"  "X623"  "X624"  "X625"  "X626"  "X627"  "X628"
#  [280] "X629"  "X630"  "X631"  "X632"  "X633"  "X634"  "X635"  "X636"  "X637"
#  [289] "X638"  "X639"  "X640"  "X641"  "X642"  "X643"  "X644"  "X645"  "X646"
#  [298] "X647"  "X648"  "X649"  "X650"  "X651"  "X652"  "X653"  "X654"  "X655"
#  [307] "X656"  "X657"  "X658"  "X659"  "X660"  "X661"  "X662"  "X663"  "X664"
#  [316] "X665"  "X666"  "X667"  "X668"  "X669"  "X670"  "X671"  "X672"  "X673"
#  [325] "X674"  "X675"  "X676"  "X677"  "X678"  "X679"  "X680"  "X681"  "X682"
#  [334] "X683"  "X684"  "X685"  "X686"  "X687"  "X688"  "X689"  "X690"  "X691"
#  [343] "X692"  "X693"  "X694"  "X695"  "X696"  "X697"  "X698"  "X699"  "X700"
#  [352] "X701"  "X702"  "X703"  "X704"  "X705"  "X706"  "X707"  "X708"  "X709"
#  [361] "X710"  "X711"  "X712"  "X713"  "X714"  "X715"  "X716"  "X717"  "X718"
#  [370] "X719"  "X720"  "X721"  "X722"  "X723"  "X724"  "X725"  "X726"  "X727"
#  [379] "X728"  "X729"  "X730"  "X731"  "X732"  "X733"  "X734"  "X735"  "X736"
#  [388] "X737"  "X738"  "X739"  "X740"  "X741"  "X742"  "X743"  "X744"  "X745"
#  [397] "X746"  "X747"  "X748"  "X749"  "X750"  "X751"  "X752"  "X753"  "X754"
#  [406] "X755"  "X756"  "X757"  "X758"  "X759"  "X760"  "X761"  "X762"  "X763"
#  [415] "X764"  "X765"  "X766"  "X767"  "X768"  "X769"  "X770"  "X771"  "X772"
#  [424] "X773"  "X774"  "X775"  "X776"  "X777"  "X778"  "X779"  "X780"  "X781"
#  [433] "X782"  "X783"  "X784"  "X785"  "X786"  "X787"  "X788"  "X789"  "X790"
#  [442] "X791"  "X792"  "X793"  "X794"  "X795"  "X796"  "X797"  "X798"  "X799"
#  [451] "X800"  "X801"  "X802"  "X803"  "X804"  "X805"  "X806"  "X807"  "X808"
#  [460] "X809"  "X810"  "X811"  "X812"  "X813"  "X814"  "X815"  "X816"  "X817"
#  [469] "X818"  "X819"  "X820"  "X821"  "X822"  "X823"  "X824"  "X825"  "X826"
#  [478] "X827"  "X828"  "X829"  "X830"  "X831"  "X832"  "X833"  "X834"  "X835"
#  [487] "X836"  "X837"  "X838"  "X839"  "X840"  "X841"  "X842"  "X843"  "X844"
#  [496] "X845"  "X846"  "X847"  "X848"  "X849"  "X850"  "X851"  "X852"  "X853"
#  [505] "X854"  "X855"  "X856"  "X857"  "X858"  "X859"  "X860"  "X861"  "X862"
# %%
used_bands <- c(
    "X397.593_5nm",
    "X402.593_5nm",
    "X407.593_5nm",
    "X412.593_5nm",
    "X417.593_5nm",
    "X422.593_5nm",
    "X427.593_5nm",
    "X432.593_5nm",
    "X437.593_5nm",
    "X442.593_5nm",
    "X447.593_5nm",
    "X452.593_5nm",
    "X457.593_5nm",
    "X462.593_5nm",
    "X467.593_5nm",
    "X472.593_5nm",
    "X477.593_5nm",
    "X482.593_5nm",
    "X487.593_5nm",
    "X492.593_5nm",
    "X497.593_5nm",
    "X502.593_5nm",
    "X507.593_5nm",
    "X512.593_5nm",
    "X517.593_5nm",
    "X522.593_5nm",
    "X527.593_5nm",
    "X532.593_5nm",
    "X537.593_5nm",
    "X542.593_5nm",
    "X547.593_5nm",
    "X552.593_5nm",
    "X557.593_5nm",
    "X562.593_5nm",
    "X567.593_5nm",
    "X572.593_5nm",
    "X577.593_5nm",
    "X582.593_5nm",
    "X587.593_5nm",
    "X592.593_5nm",
    "X597.593_5nm",
    "X602.593_5nm",
    "X607.593_5nm",
    "X612.593_5nm",
    "X617.593_5nm",
    "X622.593_5nm",
    "X627.593_5nm",
    "X632.593_5nm",
    "X637.593_5nm",
    "X642.593_5nm",
    "X647.593_5nm",
    "X652.593_5nm",
    "X657.593_5nm",
    "X662.593_5nm",
    "X667.593_5nm",
    "X672.593_5nm",
    "X677.593_5nm",
    "X682.593_5nm",
    "X687.593_5nm",
    "X692.593_5nm",
    "X697.593_5nm",
    "X702.593_5nm",
    "X707.593_5nm",
    "X712.593_5nm",
    "X717.593_5nm",
    "X722.593_5nm",
    "X727.593_5nm",
    "X732.593_5nm",
    "X737.593_5nm",
    "X742.593_5nm",
    "X747.593_5nm",
    "X752.593_5nm",
    "X757.593_5nm",
    "X762.593_5nm",
    "X767.593_5nm",
    "X772.593_5nm",
    "X777.593_5nm",
    "X782.593_5nm",
    "X787.593_5nm",
    "X792.593_5nm",
    "X797.593_5nm",
    "X802.593_5nm",
    "X807.593_5nm",
    "X812.593_5nm",
    "X817.593_5nm",
    "X822.593_5nm",
    "X827.593_5nm",
    "X832.593_5nm",
    "X837.593_5nm",
    "X842.593_5nm",
    "X847.593_5nm",
    "X852.593_5nm",
    "X857.593_5nm",
    "X862.593_5nm",
    "X867.593_5nm",
    "X872.593_5nm",
    "X877.593_5nm",
    "X882.593_5nm",
    "X887.593_5nm",
    "X892.593_5nm",
    "X897.593_5nm",
    "X902.593_5nm",
    "X907.593_5nm",
    "X912.593_5nm",
    "X917.593_5nm",
    "X922.593_5nm",
    "X927.593_5nm",
    "X932.593_5nm",
    "X937.593_5nm",
    "X942.593_5nm",
    "X947.593_5nm",
    "X952.593_5nm",
    "X957.593_5nm",
    "X962.593_5nm",
    "X967.593_5nm",
    "X972.593_5nm",
    "X977.593_5nm",
    "X982.593_5nm",
    "X987.593_5nm",
    "X992.593_5nm"
)

ground_spectra <- veg_indices[,used_bands]

# %%
head(ground_spectra)
# Out:
#   X397.593_5nm X402.593_5nm X407.593_5nm X412.593_5nm X417.593_5nm X422.593_5nm
# 1 4.962204     4.786391     4.478547     4.214955     4.121219     4.261843
# 2 4.955630     4.820802     4.623885     4.461647     4.424839     4.589012
# 3 6.099001     5.849977     5.496151     5.154779     4.986053     5.175844
# 4 6.521091     6.252788     5.817240     5.399310     5.201525     5.424306
# 5 5.284436     5.055413     4.732800     4.457956     4.357744     4.533789
# 6 6.409841     6.056797     5.514715     5.001802     4.665174     4.565842
#   X427.593_5nm X432.593_5nm X437.593_5nm X442.593_5nm ⋯ X947.593_5nm
# 1 4.609276     5.056049     5.609938      6.384817    ⋯ 26.59656
# 2 4.933364     5.350729     5.836299      6.480323    ⋯ 21.41355
# 3 5.731791     6.499972     7.520754      9.011172    ⋯ 31.84974
# 4 6.092052     7.068518     8.364273     10.123249    ⋯ 34.18603
# 5 4.989059     5.639766     6.534486      7.839488    ⋯ 29.14092
# 6 4.598097     4.511881     4.293868      4.154127    ⋯ 47.87045
#   X952.593_5nm X957.593_5nm X962.593_5nm X967.593_5nm X972.593_5nm X977.593_5nm
# 1 26.71230     26.78679     26.84674     26.92454     27.04128     27.20405
# 2 21.52685     21.62140     21.70847     21.80113     21.90688     22.02912
# 3 31.90839     31.98678     32.05158     32.08263     32.12036     32.19709
# 4 34.21727     34.23974     34.25062     34.25074     34.25434     34.27278
# 5 29.20809     29.27031     29.31446     29.34322     29.40614     29.53721
# 6 47.74562     47.59385     47.48448     47.45815     47.44645     47.39159
#   X982.593_5nm X987.593_5nm X992.593_5nm
# 1 27.38601     27.55660     27.69153
# 2 22.16226     22.29784     22.42359
# 3 32.29237     32.38387     32.46974
# 4 34.30264     34.34254     34.40410
# 5 29.70353     29.86498     29.99403
# 6 47.31926     47.26754     47.26835

# %%
# Targets 
targets <- veg_indices[!is.na(veg_indices$Functional_group1),"Functional_group1"] %>% as.factor()
# weights
weights_by_pft <- targets_to_weights(targets)

# %%
# image-based validation
uav_speclib_df <- read.csv(
    "Data/D_002_Image_SpecLib_Derivs.csv",
    header = TRUE
    )
print(colnames(uav_speclib_df))

image_validation <- uav_speclib_df[,7:(ncol(uav_speclib_df))]
validation_labels <- uav_speclib_df$Functional_group1 %>% as.factor()
#levels(validation_labels) <- c(levels(validation_labels), "Forb") 
print(colnames(image_validation))
# Out:
#   [1] "X"                 "UID"               "ScanNum"
#   [4] "sample_name"       "Species_name"      "Functional_group1"
#   [7] "Boochs"            "Boochs2"           "CARI"
#  [10] "Carter"            "Carter2"           "Carter3"
#  [13] "Carter4"           "Carter5"           "Carter6"
#  [16] "CI"                "CI2"               "ClAInt"
#  [19] "CRI1"              "CRI2"              "CRI3"
#  [22] "CRI4"              "D1"                "D2"
#  [25] "Datt"              "Datt2"             "Datt3"
#  [28] "Datt4"             "Datt5"             "Datt6"
#  [31] "DD"                "DDn"               "DPI"
#  [34] "DWSI4"             "EGFN"              "EGFR"
#  [37] "EVI"               "GDVI2"             "GDVI3"
#  [40] "GDVI4"             "GI"                "Gitelson"
#  [43] "Gitelson2"         "GMI1"              "GMI2"
#  [46] "GreenNDVI"         "Maccioni"          "MCARI"
#  [49] "MCARIOSAVI"        "MCARI2"            "MCARI2OSAVI2"
#  [52] "mND705"            "mNDVI"             "MPRI"
#  [55] "MSAVI"             "mSR"               "mSR2"
#  [58] "mSR705"            "MTCI"              "MTVI"
#  [61] "NDVI"              "NDVI2"             "NDVI3"
#  [64] "NPCI"              "OSAVI"             "OSAVI2"
#  [67] "PARS"              "PRI"               "PRInorm"
#  [70] "PRICI2"            "PSND"              "PSRI"
#  [73] "PSSR"              "RDVI"              "REPLE"
#  [76] "REPLi"             "SAVI"              "SIPI"
#  [79] "SPVI"              "SR"                "SR1"
#  [82] "SR2"               "SR3"               "SR4"
#  [85] "SR5"               "SR6"               "SR7"
#  [88] "SR8"               "SRPI"              "SumDr1"
#  [91] "SumDr2"            "TCARI"             "TCARIOSAVI"
#  [94] "TCARI2"            "TCARI2OSAVI2"      "TGI"
#  [97] "TVI"               "Vogelmann"         "Vogelmann2"
# [100] "Vogelmann3"        "Vogelmann4"
#  [1] "Boochs"       "Boochs2"      "CARI"         "Carter"       "Carter2"
#  [6] "Carter3"      "Carter4"      "Carter5"      "Carter6"      "CI"
# [11] "CI2"          "ClAInt"       "CRI1"         "CRI2"         "CRI3"
# [16] "CRI4"         "D1"           "D2"           "Datt"         "Datt2"
# [21] "Datt3"        "Datt4"        "Datt5"        "Datt6"        "DD"
# [26] "DDn"          "DPI"          "DWSI4"        "EGFN"         "EGFR"
# [31] "EVI"          "GDVI2"        "GDVI3"        "GDVI4"        "GI"
# [36] "Gitelson"     "Gitelson2"    "GMI1"         "GMI2"         "GreenNDVI"
# [41] "Maccioni"     "MCARI"        "MCARIOSAVI"   "MCARI2"       "MCARI2OSAVI2"
# [46] "mND705"       "mNDVI"        "MPRI"         "MSAVI"        "mSR"
# [51] "mSR2"         "mSR705"       "MTCI"         "MTVI"         "NDVI"
# [56] "NDVI2"        "NDVI3"        "NPCI"         "OSAVI"        "OSAVI2"
# [61] "PARS"         "PRI"          "PRInorm"      "PRICI2"       "PSND"
# [66] "PSRI"         "PSSR"         "RDVI"         "REPLE"        "REPLi"
# [71] "SAVI"         "SIPI"         "SPVI"         "SR"           "SR1"
# [76] "SR2"          "SR3"          "SR4"          "SR5"          "SR6"
# [81] "SR7"          "SR8"          "SRPI"         "SumDr1"       "SumDr2"
# [86] "TCARI"        "TCARIOSAVI"   "TCARI2"       "TCARI2OSAVI2" "TGI"
# [91] "TVI"          "Vogelmann"    "Vogelmann2"   "Vogelmann3"   "Vogelmann4"

# %%
image_band_file <- "Data/Ground_Validation/PFT_Image_spectra/PFT_Image_SpectralLib_Clean.csv"
image_bands_base <- read.csv(image_band_file, header = TRUE)
head(image_bands_base)
# Out:
#   X UID                   ScanNum sample_name PFT    FncGrp1       X398
# 1 1 BisonGulchPFTsBetula1 1       spec_1      Betula TreeBroadleaf 0.05243007
# 2 2 BisonGulchPFTsBetula1 1       spec_2      Betula TreeBroadleaf 0.03280578
# 3 3 BisonGulchPFTsBetula1 1       spec_3      Betula TreeBroadleaf 0.02415163
# 4 4 BisonGulchPFTsBetula1 1       spec_4      Betula TreeBroadleaf 0.03013168
# 5 5 BisonGulchPFTsBetula1 1       spec_5      Betula TreeBroadleaf 0.02798701
# 6 6 BisonGulchPFTsBetula1 1       spec_6      Betula TreeBroadleaf 0.01771090
#   X399       X400       X401       ⋯ X990      X991      X992      X993
# 1 0.04516057 0.03909831 0.03482924 ⋯ 0.5636831 0.5717859 0.5632404 0.5485100
# 2 0.03279741 0.03278975 0.03278255 ⋯ 0.4652565 0.4655240 0.4657567 0.4659595
# 3 0.02445285 0.02475288 0.02505101 ⋯ 0.4713047 0.4704058 0.4696060 0.4689031
# 4 0.03041985 0.03070853 0.03097938 ⋯ 0.4282925 0.4317823 0.4380752 0.4476607
# 5 0.02818876 0.02838857 0.02858507 ⋯ 0.4344142 0.4353318 0.4362373 0.4371232
# 6 0.02832461 0.03569997 0.04027814 ⋯ 0.6276267 0.6381394 0.6008782 0.5358806
#   X994      X995      X996      X997      X998      X999
# 1 0.5380677 0.5400187 0.5561121 0.5870420 0.6335022 0.6961869
# 2 0.4661377 0.4662962 0.4664396 0.4665724 0.4666992 0.4668245
# 3 0.4682946 0.4677750 0.4673299 0.4669434 0.4665996 0.4662826
# 4 0.4610279 0.4783732 0.4991071 0.5225098 0.5478615 0.5744424
# 5 0.4379823 0.4388103 0.4396119 0.4403929 0.4411592 0.4419167
# 6 0.4632139 0.3988209 0.3475733 0.3125049 0.2966494 0.3030405

# %%
head(uav_speclib_df)
# Out:
#   X UID                   ScanNum sample_name Species_name Functional_group1
# 1 1 BisonGulchPFTsBetula1 1       spec_1      Betula       TreeBroadleaf
# 2 2 BisonGulchPFTsBetula1 1       spec_2      Betula       TreeBroadleaf
# 3 3 BisonGulchPFTsBetula1 1       spec_3      Betula       TreeBroadleaf
# 4 4 BisonGulchPFTsBetula1 1       spec_4      Betula       TreeBroadleaf
# 5 5 BisonGulchPFTsBetula1 1       spec_5      Betula       TreeBroadleaf
# 6 6 BisonGulchPFTsBetula1 1       spec_6      Betula       TreeBroadleaf
#   Boochs     Boochs2    CARI      Carter   ⋯ TCARI     TCARIOSAVI TCARI2
# 1 0.04458108 0.04740075 0.4024937 2.590460 ⋯ 0.1839101 0.2537528  0.2929463
# 2 0.03563080 0.04161413 0.4942408 3.302811 ⋯ 0.2099215 0.2861469  0.2999738
# 3 0.03453174 0.04008770 0.5239385 3.961739 ⋯ 0.2133080 0.2947130  0.3059068
# 4 0.04207259 0.04885354 0.3876063 3.001123 ⋯ 0.1820928 0.2479048  0.2860024
# 5 0.03259095 0.03898760 0.5114026 3.418290 ⋯ 0.1983424 0.2604261  0.2756164
# 6 0.04595668 0.04410418 0.3418377 2.189309 ⋯ 0.1661865 0.2251088  0.2613359
#   TCARI2OSAVI2 TGI      TVI      Vogelmann Vogelmann2  Vogelmann3 Vogelmann4
# 1 0.6558584    5.602349 27.39160 1.499247  -0.10016087 0.9650307  -0.1105040
# 2 0.6978696    5.870123 27.46331 1.466579  -0.10421401 1.1289388  -0.1133807
# 3 0.7366110    5.749202 27.35307 1.451390  -0.10566083 1.1220095  -0.1144487
# 4 0.6078135    5.799982 28.38082 1.507632  -0.09821639 1.0927509  -0.1084488
# 5 0.6326965    5.356984 27.02998 1.493435  -0.12272793 1.1400077  -0.1336198
# 6 0.5537832    5.423731 27.07097 1.538385  -0.10291525 0.8754768  -0.1143752

# %% [markdown]
# ## Base transformation
# This removes infinity, outliers and NAs from the data.

# %%
numeric_data <- veg_indices[!is.na(veg_indices$Functional_group1),35:(ncol(veg_indices)-1)]
numeric_data <- inf_to_na(numeric_data)
imputed_data_1 <- impute_spectra(numeric_data)
imputed_data_no_outliers <- outliers_to_na(imputed_data_1)
imputed_data <- impute_spectra(imputed_data_no_outliers)
outlier_indices <- detect_outliers_columnwise(imputed_data[,1:95])
filtered_data <- imputed_data[!outlier_indices,]
hist(dist(as.matrix(imputed_data)))
min_max_scaled_data <- columnwise_min_max_scale(imputed_data)
# Out:
# [1] "Imputing..."
# [1] "Imputing..."
# Plot with title “Histogram of dist(as.matrix(imputed_data))”

# %%
print(colnames(imputed_data))
# Out:
#   [1] "Boochs"       "Boochs2"      "CARI"         "Carter"       "Carter2"
#   [6] "Carter3"      "Carter4"      "Carter5"      "Carter6"      "CI"
#  [11] "CI2"          "ClAInt"       "CRI1"         "CRI2"         "CRI3"
#  [16] "CRI4"         "D1"           "D2"           "Datt"         "Datt2"
#  [21] "Datt3"        "Datt4"        "Datt5"        "Datt6"        "DD"
#  [26] "DDn"          "DPI"          "DWSI4"        "EGFN"         "EGFR"
#  [31] "EVI"          "GDVI2"        "GDVI3"        "GDVI4"        "GI"
#  [36] "Gitelson"     "Gitelson2"    "GMI1"         "GMI2"         "GreenNDVI"
#  [41] "Maccioni"     "MCARI"        "MCARIOSAVI"   "MCARI2"       "MCARI2OSAVI2"
#  [46] "mND705"       "mNDVI"        "MPRI"         "MSAVI"        "mSR"
#  [51] "mSR2"         "mSR705"       "MTCI"         "MTVI"         "NDVI"
#  [56] "NDVI2"        "NDVI3"        "NPCI"         "OSAVI"        "OSAVI2"
#  [61] "PARS"         "PRI"          "PRInorm"      "PRICI2"       "PSND"
#  [66] "PSRI"         "PSSR"         "RDVI"         "REPLE"        "REPLi"
#  [71] "SAVI"         "SIPI"         "SPVI"         "SR"           "SR1"
#  [76] "SR2"          "SR3"          "SR4"          "SR5"          "SR6"
#  [81] "SR7"          "SR8"          "SRPI"         "SumDr1"       "SumDr2"
#  [86] "TCARI"        "TCARIOSAVI"   "TCARI2"       "TCARI2OSAVI2" "TGI"
#  [91] "TVI"          "Vogelmann"    "Vogelmann2"   "Vogelmann3"   "Vogelmann4"
#  [96] "X397.593_5nm" "X402.593_5nm" "X407.593_5nm" "X412.593_5nm" "X417.593_5nm"
# [101] "X422.593_5nm" "X427.593_5nm" "X432.593_5nm" "X437.593_5nm" "X442.593_5nm"
# [106] "X447.593_5nm" "X452.593_5nm" "X457.593_5nm" "X462.593_5nm" "X467.593_5nm"
# [586] "X977"        "X978"        "X979"        "X980"        "X981"
# [591] "X982"        "X983"        "X984"        "X985"        "X986"
# [596] "X987"        "X988"        "X989"        "X990"        "X991"
# [601] "X992"        "X993"        "X994"        "X995"        "X996"
# [606] "X997"        "X998"        "X999"

# %% [markdown]
# ## Transform the Image-based Data

# %%
veg_index_names <- read.csv("assets/vegIndicesUsed.csv")$x
validation_indices <- get_vegetation_indices(image_bands_base[,7:ncol(image_bands_base)], NULL)
# drop NAs

validation_indices <- inf_to_na(validation_indices)
validation_indices <- impute_spectra(validation_indices)
validation_indices <- outliers_to_na(validation_indices)
validation_indices <- impute_spectra(validation_indices)


min_max_scaled_validation <- columnwise_min_max_scale(validation_indices)

#hist(as.matrix(min_max_scaled_validation))
# Out:
# [1] "Imputing..."

# %%
# Out:
# [1] 62

# %%
print(colnames(image_bands_base[,7:ncol(image_bands_base)]))

# %%
validation_bands <- resample_df(image_bands_base[,7:ncol(image_bands_base)],normalize = FALSE,    min_wavelength = 397.593+5,
    max_wavelength = 995.716,
    delta = 5)

# %%
print(dim(validation_bands))
print(length(validation_labels))

# %%
head(validation_bands*100)
head(imputed_data)

# %%
print(colnames(validation_bands))

# %%
image_weights <- targets_to_weights(validation_labels %>% as.factor())

# %%
# generate the test data
set.seed(61718L)
print(validation_labels)
permutation <- permute::shuffle(length(validation_labels))
val_t_chars <- validation_labels[permutation] %>% as.character()
print(val_t_chars[1:5])
counts <- c(0,0,0,0,0,0,0,0,0)
samples <- vector(mode = "logical", length=length(validation_labels))

for(i in seq_along(val_t_chars)){
    samples[[i]] <- FALSE
    if(val_t_chars[[i]] == "Abiotic"){
        if(counts[[1]]<31){
            samples[[i]] <-  TRUE
            counts[[1]] <- counts[[1]] + 1
        }

    } else if (val_t_chars[[i]] == "Graminoid"){
        if(counts[[2]] < 31){
            samples[[i]] <-  TRUE
            counts[[2]] <- counts[[2]] + 1
        }
    } else if (val_t_chars[[i]] == "Forb"){
        if(counts[[3]] < 31){
            samples[[i]] <-  TRUE
            counts[[3]] <- counts[[3]] + 1
        }
    } else if (val_t_chars[[i]] == "Lichen"){
        if(counts[[4]] < 31){
            samples[[i]] <-  TRUE
            counts[[4]] <- counts[[4]] + 1
        }
    } else if (val_t_chars[[i]] == "Moss"){
        if(counts[[5]] < 31){
            samples[[i]] <-  TRUE
            counts[[5]] <- counts[[5]] + 1
        }
    } else if (val_t_chars[[i]] == "ShrubDecid"){
        if(counts[[6]] < 31){
            samples[[i]] <-  TRUE
            counts[[6]] <- counts[[6]] + 1
        }
    } else if (val_t_chars[[i]] == "ShrubEvergreen"){
        if(counts[[7]] < 31){
            samples[[i]] <-  TRUE
            counts[[7]] <- counts[[7]] + 1
        }
    } else if (val_t_chars[[i]] == "TreeConifer"){
        if(counts[[8]] < 31){
            samples[[i]] <-  TRUE
            counts[[8]] <- counts[[8]] + 1
        }
    } else if (val_t_chars[[i]] == "TreeBroadleaf"){
        if(counts[[9]] < 31){
            samples[[i]] <-  TRUE
            counts[[9]] <- counts[[9]] + 1
        }
    }
}


temp <- validation_labels[permutation] %>% as.factor()
test_labels <- temp[as.vector(samples)]
temp <- cbind(validation_bands[permutation,], validation_indices[permutation,]) %>% as.data.frame()
test_data <- temp[as.vector(samples),]
# Out:
#    [1] TreeBroadleaf  TreeBroadleaf  TreeBroadleaf  TreeBroadleaf
TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4169] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4173] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4177] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4181] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4185] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4189] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4193] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4197] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4201] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4205] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4209] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4213] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4217] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4221] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4225] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4229] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4233] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4237] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4241] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4245] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4249] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4253] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4257] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4261] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4265] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4269] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4273] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4277] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4281] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4285] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4289] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4293] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4297] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4301] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4305] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4309] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4313] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4317] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4321] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4325] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4329] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4333] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4337] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4341] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4345] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4349] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4353] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4357] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4361] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4365] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4369] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4373] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4377] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4381] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4385] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4389] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4393] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4397] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4401] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4405] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4409] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4413] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4417] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4421] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4425] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4429] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4433] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4437] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4441] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4445] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4449] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4453] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4457] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4461] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4465] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4469] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4473] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4477] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4481] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4485] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4489] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4493] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4497] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4501] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4505] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4509] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4513] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4517] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4521] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4525] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4529] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4533] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4537] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4541] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4545] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4549] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4553] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4557] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4561] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4565] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4569] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4573] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4577] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4581] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4585] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4589] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4593] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4597] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4601] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4605] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4609] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4613] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4617] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4621] TreeConifer    TreeConifer    TreeConifer    TreeConifer
# [4625] Moss           Moss           Moss           Moss
# [4629] Moss           Moss           Moss           Moss
# [4633] Moss           Moss           Moss           Moss
# [4637] Moss           Moss           Moss           Moss
# [4641] Moss           Moss           Moss           Moss
# [4645] Moss           Moss           Moss           Moss
# [4649] Moss           Moss           Moss           Moss
# [4653] Moss           Moss           Moss           Moss
# [4657] Moss           Moss           Moss           Moss
# [4661] Moss           Moss           Moss           Moss
# [4665] Moss           Moss           Moss           Moss
# [4669] Moss           Moss           Moss           Moss
# [4673] Moss           Moss           Moss           Moss
# [4677] Moss           Moss           Moss           Moss
# [4681] Moss           Moss
# 8 Levels: Abiotic Graminoid Lichen Moss ShrubDecid ... TreeConifer
# [1] "Lichen"         "TreeConifer"    "TreeConifer"    "ShrubEvergreen"
# [5] "TreeConifer"

# %%
create_matched_data <- function(left_df, right_df, cols = c("targets", "targets")){
    
    shared_levels <- intersect(
        levels(as.factor(left_df[, cols[1]])), 
        levels(as.factor(right_df[, cols[[2]]]))
        )

    # store inermediate results in a list
    level_dfs_l <- NULL
    level_dfs_r <- NULL

    for( level in shared_levels){
        filtered_left <- left_df[(left_df[,cols[[1]]] == level),]
        filtered_right <- right_df[right_df[,cols[[2]]] == level,]

        permutation_left <- permute::shuffle(nrow(filtered_left))
        permutation_right <- permute::shuffle(nrow(filtered_right))

        num_records <- min(nrow(filtered_left), nrow(filtered_right))
        
        if(num_records > 0){
            if(is.null(level_dfs_l)){
                level_dfs_l <- filtered_left[1:num_records,]
            } else {
                level_dfs_l <- rbind(level_dfs_l, filtered_left[permutation_left[1:num_records],])
            }

            if(is.null(level_dfs_r)){
                level_dfs_r <- filtered_right[1:num_records,]
            } else {
                level_dfs_r <- rbind(level_dfs_r, filtered_right[permutation_right[1:num_records],])
            }

        }
    }

    return(list(
        left = level_dfs_l,
        right = level_dfs_r
    ))


}

# %%
# match the samples between the data and create a matched dataset
all_ground <- imputed_data
all_ground$targets <- targets


all_image <- validation_bands
all_image$targets <- validation_labels

# %%
matched_data <- create_matched_data(
    all_ground,
    all_image,
)

# %%
build_columnwise_sensor_correction_model <- function(
    left_df, 
    right_df, 
    ignore_cols = NULL,
    verbose = TRUE
) {

    used_cols <- intersect(
        colnames(left_df),
        colnames(right_df)
    )

    if(!is.null(ignore_cols)){
        used_cols <- setdiff(used_cols, ignore_cols)
    }


    models  <- list()

    for(col in used_cols){
        left_vec <- sort(left_df[,col])
        right_vec <- sort(right_df[,col])
        if(is.numeric(left_vec) & is.numeric(right_vec)){
            model <- lm(
                left_vec~right_vec,
                )

            if(verbose){
                print(summary(model))
            }
            models[[col]] <- model
        }
    }

    return(models)
}

# %%
apply_sensor_correction_model <- function(
    models,
    data,
    ignore_cols = NULL
){
    used_cols <- colnames(data)
     if(!is.null(ignore_cols)){
        used_cols <- setdiff(used_cols, ignore_cols)
    }

    df_corrected <- as.data.frame(data)

    for(col in used_cols){
        if(!is.null(models[[col]])){
            print(paste0("Correcting ", col))
            model_intercept <- summary(models[[col]])$coefficients[1,1]
            model_slope <- summary(models[[col]])$coefficients[2,1]
            df_corrected[,col] <- model_intercept + (data[,col]*model_slope)
        }
    }

    return(df_corrected)
}

# %%
correction_models <- build_columnwise_sensor_correction_model(matched_data$left, matched_data$right)

# %%
print(colnames(validation_bands[,603:ncol(validation_bands)]))
validation_bands <- validation_bands[,603:ncol(validation_bands)]

# %%
transformed_data <- apply_sensor_correction_model(
    correction_models,
    imputed_data
)

head(transformed_data)
head(imputed_data)

# %%
corrected_ground_indices <- impute_spectra(
    get_vegetation_indices(transformed_data, NULL)
)

head(corrected_ground_indices)

# %%
# generate the test data
set.seed(61718L)
permutation <- permute::shuffle(targets)
val_t_chars <- targets[permutation] %>% as.character()
print(val_t_chars[1:5])
counts <- c(0,0,0,0,0,0,0,0,0)
samples <- vector(mode = "logical", length=length(targets))

for(i in seq_along(val_t_chars)){
    samples[[i]] <- FALSE
    if(val_t_chars[[i]] == "Abiotic"){
        if(counts[[1]]<31){
            samples[[i]] <-  TRUE
            counts[[1]] <- counts[[1]] + 1
        }

    } else if (val_t_chars[[i]] == "Graminoid"){
        if(counts[[2]] < 31){
            samples[[i]] <-  TRUE
            counts[[2]] <- counts[[2]] + 1
        }
    } else if (val_t_chars[[i]] == "Forb"){
        if(counts[[3]] < 31){
            samples[[i]] <-  TRUE
            counts[[3]] <- counts[[3]] + 1
        }
    } else if (val_t_chars[[i]] == "Lichen"){
        if(counts[[4]] < 31){
            samples[[i]] <-  TRUE
            counts[[4]] <- counts[[4]] + 1
        }
    } else if (val_t_chars[[i]] == "Moss"){
        if(counts[[5]] < 31){
            samples[[i]] <-  TRUE
            counts[[5]] <- counts[[5]] + 1
        }
    } else if (val_t_chars[[i]] == "ShrubDecid"){
        if(counts[[6]] < 31){
            samples[[i]] <-  TRUE
            counts[[6]] <- counts[[6]] + 1
        }
    } else if (val_t_chars[[i]] == "ShrubEvergreen"){
        if(counts[[7]] < 31){
            samples[[i]] <-  TRUE
            counts[[7]] <- counts[[7]] + 1
        }
    } else if (val_t_chars[[i]] == "TreeConifer"){
        if(counts[[8]] < 31){
            samples[[i]] <-  TRUE
            counts[[8]] <- counts[[8]] + 1
        }
    } else if (val_t_chars[[i]] == "TreeBroadleaf"){
        if(counts[[9]] < 31){
            samples[[i]] <-  TRUE
            counts[[9]] <- counts[[9]] + 1
        }
    }
}


temp <- targets[permutation] %>% as.factor()
train_labels <- temp[as.vector(samples)]
temp <- cbind(validation_bands, validation_indices)[permutation,] %>% as.data.frame()
train_data <- temp[as.vector(samples),]

# %% [markdown]
# ## PCA
# This is where we calcuate PCA for the ground and image spectra

# %%
# fit a PCA to the ground spectra
pca_fit <- stats::prcomp(imputed_data[,1:(ncol(numeric_data) - 66)], center = FALSE, scale. = FALSE)
print(summary(pca_fit))
pca_training_data <- predict(pca_fit, imputed_data[,1:(ncol(numeric_data) - 66)])[,1:64]
boxplot(vegan::scores(pca_training_data)[,2]~targets)

# %% [markdown]
# ## Standardization
# This cell standardizes the input to center at zero with standard deviation one.

# %%
# standardization
indice_standardizer <- caret::preProcess(imputed_data[,1:95])
standardized_indices <- predict(indice_standardizer, imputed_data[,1:95])

val_standardizer <- caret::preProcess(validation_indices)
standardized_validation <- predict(val_standardizer, validation_indices)

# %%
hist(standardized_indices$Carter, breaks = 20)
hist(standardized_validation$Carter, breaks = 20)

# %% [markdown]
# ## Min-Max Scaling
# This executes the min-man scalaing (to make the data on the scale [0,1])

# %%
# plots
#hist(min_max_scaled_validation %>% as.matrix())
#hist(min_max_scaled_data %>% as.matrix())
print(colnames(validation_indices))
print(str(pca_fit))
#pca_validation_data <- predict(pca_fit, validation_indices)[,1:64] %>% as.data.frame()
#boxplot(vegan::scores(pca_validation_data)[,2]~validation_labels)

# %% [markdown]
# ## KS Tests of Transferrability
# These next few cells test whether the veg indices are similarly distributed (i.e. could be samples drawn from the same distribution)
#
# The hypothesis is that columns (veg indices) that pass this test can safely be used across models and conditions (are transferrable)

# %%
source("Functions/lecospectR.R")
ks_test_results <- test_transferrability(matched_data$left, matched_data$right)
print(ks_test_results)

# %% [markdown]
# ## t-SNE
# Examine the clusters in the data via *t*-SNE

# %%
library(Rtsne)
unique_indices <- imputed_data[!duplicated(imputed_data),1:95]
normalized_veg_indices <- Rtsne::normalize_input(
    unique_indices %>% 
    as.matrix()
    )
embedding_2D <- Rtsne::Rtsne(normalized_veg_indices)
print(names(embedding_2D))

plot(embedding_2D$Y, col = as.factor(targets))
par(xpd=T)
legend("topright", legend = unique(targets), col = seq_along(unique(targets)),pch = 1)

# %% [markdown]
# ## Vector Quantization Classifier
# This fits a LVQ classifier to the data and then

# %%
print(length(validation_labels))
print(nrow(min_max_scaled_validation))

# %% [markdown]
# ## Train-Test Split
#
# Perform an 80-20 split on the data (use the split on the fly during the grid search)

# %%
grd_train_idx <- caTools::sample.split(targets, SplitRatio = 0.8)

# %%
img_train_idx <- caTools::sample.split(validation_labels, SplitRatio = 0.8)

# %% [markdown]
# ## Random Forest
# trains a random forest model

# %%
rf_model <- ranger::ranger(
    num.trees = 1024,
    #case.weights = targets_to_weights(validation_labels),
    importance = "impurity",
    classification = TRUE,
    x = columnwise_robust_scale(
        test_data
    ),
    y = test_labels
)

print(rf_model)
# Out:
# Ranger result
#
# Call:
#  ranger::ranger(num.trees = 1024, importance = "impurity", classification = TRUE,      x = columnwise_robust_scale(test_data), y = test_labels)
#
# Type:                             Classification
# Number of trees:                  1024
# Sample size:                      248
# Number of independent variables:  214
# Mtry:                             14
# Target node size:                 1
# Variable importance mode:         impurity
# Splitrule:                        gini
# OOB prediction error:             11.29 %

# %%
print(setdiff(colnames(transformed_data), colnames(test_data)))

# %%
predictions <- predict(rf_model, test_data)$predictions %>% 
    as.factor()

    #levels(test_labels) <- c(levels(test_labels), "Forb")
confusion_matrix <- caret::confusionMatrix(
    predictions, 
    test_labels, 
    mode = "everything")


print(confusion_matrix)

# %%
save(rf_model, file="mle/models/gs/rf_img_robust_min.rda")

# %%
important_variables <- sort(rf_model$variable.importance, decreasing = TRUE)
print(important_variables)

# %%
important_variable_names<- names(important_variables)
print(important_variable_names)

# %%
print(test_labels %>% table())

# %%
head(matched_data$left)

# %%
head(matched_data$right)

# %%
write_tukey_symmetric_difference_plots <- function(
    left_df,
    right_df,
    save_directory = "./", 
    ignore_cols = NULL
) {
    used_cols <- intersect(
        colnames(left_df),
        colnames(right_df)
    )

    if(!is.null(ignore_cols)){
        used_cols <- setdiff(used_cols, ignore_cols)
    }

    for(col in used_cols){
        y_l <- left_df[,col] 
        r_l <- right_df[,col]
        if(is.numeric(y_l) & is.numeric(r_l)){
            plt <- create_tukey_symmetric_difference_plot(
                y_l,r_l
            )
           ggsave(
            paste0(save_directory, col, ".png"),
            plot = plt
           ) 
        }



    }
}

# %%
create_tukey_symmetric_difference_plot <- function(
    left_vec,
    right_vec
) {
    average_vec <- (left_vec + right_vec) / 2
    difference_vec <- (left_vec - right_vec)

    min_average <- min(average_vec)
    max_average <- max(average_vec)

    sd_difference <- sd(difference_vec)
    mean_difference <- mean(difference_vec)
    upper_bound <- mean_difference + (1.96*sd_difference)
    lower_bound <- mean_difference - (1.96 * sd_difference)

    plt <- ggplot(
            data = NULL,
            aes(
                x=average_vec,
                y=difference_vec
            )
        ) +
        geom_point() + 
        geom_hline(
            yintercept=lower_bound,
            color="red"
        ) + 
        geom_hline(
            yintercept = upper_bound,
            color="red"
        ) +
        geom_hline(
            yintercept = mean_difference,
            color="blue"
        ) +
        ylab("Diff. Between Measures") +
        xlab("Average Measure")

    return(plt)
        
}

# %%
write_tukey_symmetric_difference_plots(
    matched_data$left,
    matched_data$right,
    save_directory = "figures/linearCorrectedPlots/"
)

# %%
write_tukey_symmetric_difference_plots(
    standardize_df(matched_data$left,ignore_cols=c("targets")),
    standardize_df(matched_data$right,ignore_cols=c("targets")),
    save_directory = "figures/standardizedDifferences/"
)

write_tukey_symmetric_difference_plots(
    columnwise_min_max_scale(matched_data$left,ignore_cols=c("targets")),
    columnwise_min_max_scale(matched_data$right,ignore_cols=c("targets")),
    save_directory = "figures/minMaxDifferences/"
)

write_tukey_symmetric_difference_plots(
    columnwise_robust_scale(matched_data$left,ignore_cols=c("targets")),
    columnwise_robust_scale(matched_data$right,ignore_cols=c("targets")),
    save_directory = "figures/scaledDifferences/"
)

# %% [markdown]
# # Grid Search
#
# This next section defines all the essentials for the grid search across our different candidate models.

# %% [markdown]
# ## Candidates
#
# ### Models
# * Random Forest
# * Learned Vector Quantization (LVQ)
# * k-Nearest Neighbor (kNN)
#
# Could also consider Support Vector Machine (SVM), Gradient Boosted Trees (e.g. LightGBM, XGBoost), matched filtering, Logistic Regression, etc.
#
# ### Data/Transformations
#
# For each of the image/training data sets, test the following:
# * raw,
# * raw (no outliers)
# * standardized (z-score standardization)
# * standardized (z-score standardization, no outliers)
# * min-max scaled
# * min-max scaled (no outliers)
# * PCA
# * PCA no outliers
#
# Need to also vary how many columns are included in the analysis

# %%
print(dim(imputed_data))
print(dim(standardized_indices))
print(dim(min_max_scaled_data))
print(dim(validation_indices))
print(dim(standardized_validation))
print(dim(min_max_scaled_validation))

# %%
print(colnames(imputed_data))

# %%
print(colnames(validation_bands))

# %%
# define the data sets to loop over
gs_train <- list(
    #pca_training_data,
    subset(transformed_data, select = -c(X397.593_5nm)),
    standardize_df(subset(transformed_data, select = -c(X397.593_5nm))),
    #standardized_indices[,important_variable_names],
    columnwise_min_max_scale(subset(transformed_data, select = -c(X397.593_5nm))),
    columnwise_robust_scale(subset(transformed_data, select = -c(X397.593_5nm)))
)

gs_preprocessing <- list(
    "None",
    "Standard Scaling (z-score)",
    "Min-Max Scaling",
    "Robust Scaling (Median/IQR)"
)

gs_test <- list(
    #cbind(validation_indices, 100*validation_bands)[permutation,][samples,],
    #cbind(standardized_validation, scale(validation_bands))[permutation,][samples,],
    #cbind(min_max_scaled_validation, columnwise_min_max_scale(validation_bands))[permutation,][samples,],
    test_data,
    standardize_df(test_data),
    columnwise_min_max_scale(test_data),
    columnwise_robust_scale(
        cbind(test_data)
    )

    #pca_validation_data[permutation,][samples,],
#    min_max_scaled_validation[permutation,][samples,],
 #   standardized_validation[permutation,][samples,]
    #pca_validation_data[-img_train_idx]

)

gs_train_labels <- list(
    targets,
    targets,
    targets,
    targets,
    targets,
    targets
)

gs_samples <- list(
    test_labels,
    test_labels,
    test_labels,
    test_labels,
    test_labels,
    test_labels,
    test_labels
)

# %%
gs_methods <- list(
    #"svmLinear",
    #"rmda",
    "RFlda",
    #"adaboost",
    #"xgbLinear",
    #"xgbTree",
    #"xgbDART",
    "svmRadialWeights",
    #"mda",
    "knn",
    #"lda",
    "ranger"
    #"hda"# heteroscedastic discriminant analysis
)
# add: PLS-LDA, kNN, SVM+poly Kernel, SVM+Exp Kernel, more boosting,

# %%
gs_weight_text <- c(
    "prior weights",
    NULL
)

gs_weights <- list(
    weights_by_pft,
    weights_by_pft,
    weights_by_pft,
    weights_by_pft,
    weights_by_pft,
    weights_by_pft,
    weights_by_pft,
    image_weights,
    image_weights,
    image_weights
)

fit_ctrl <- caret::trainControl(
    method = "repeatedcv",
    number = 10,
    repeats = 10,
    #classProbs = TRUE,
    allowParallel = TRUE
)

# %%
getwd()

# %%
for(i in seq_along(gs_train)){
    df <- data.frame(gs_train[[i]])
    test_df <- gs_test[[i]]
        
    # train and print intermediate results to console
    print("Beginning Training")
    model <- ranger::ranger(
        num.trees = 1000,
        case.weights = weights_by_pft,
        classification = TRUE,
        x=df,
        y=gs_train_labels[[i]]
    )
    print(model)


    model_predictions <- predict(
        model, 
        test_df
    )$prediction %>% as.factor()
    
    test_samples <- gs_samples[[i]] %>% as.factor()
    if(!("Forb" %in% levels(test_samples))){

        levels(test_samples) <- c(levels(test_samples), "Forb")
    }

    confusion_matrix <- caret::confusionMatrix(
        model_predictions, 
        test_samples,
        mode = "everything"
    )

    model_id <- uuid::UUIDgenerate()

    # append performance data to the logs for later comparison
    sink(file = "mle/log_rf_3.txt", append = TRUE)
    print("-------------------------------------------------------")
    print("---------------------- Model Data ---------------------")
    
    print(paste0("Model Type: Ranger (Random Forest)"))
    print(paste0("Data Index: ",i))
    print(paste0("Model UUID: ", model_id))
    print("---------------------- Confusion Matrix ---------------------")
    print(confusion_matrix)
    print("---------------------- Class Distribution ---------------------")
    print(model_predictions %>% as.factor() %>% table())
    print("-------------------------------------------------------")
    sink(NULL)


    model_metadata <- list(
        uuid = model_id,
        variables = colnames(df),
        type = "Random Forest (Ranger)",
        preprocessing = gs_preprocessing[[i]],
        saved = paste0("mle/models/gs/", model_id, ".rda"),
        results = paste0("mle/experiments/gs/", model_id, "/")
    )

    metadata_save_path <- paste0("mle/metadata/", model_id, ".json")
    json_metadata_str <- rjson::toJSON(model_metadata)
    write(json_metadata_str, file=metadata_save_path)
    
    save(model, file = paste0("mle/models/gs/", model_id, ".rda"))


    
}

# %%
R.Version()

# %%
source("Functions/lecospectR.R")

# %%
model_ids <- c(
    #"2303a2d3-f479-48b7-9840-c9f74b73836d",# ranger subset 10 >0.4
    #"6b0a0987-ff68-4f17-a3ca-7aa56284d726",# RFLDA >0.45, subset 11
    #"9f8fcf59-571d-4472-8750-7370692a2794",#RFLDA
    #"ab537b5-5141-4381-a464-5a0ff6cde137",#SVM
    #"58bee4bd-ea18-4fdb-823a-21463be3da41",#KNN predictions failed, may be clash with parallel pkg
    #"cf2b9f30-4956-4c0b-a1fe-79af7590cac9",#Ranger
    #"0c63dd43-79fe-45dd-b95f-ac8d6b2d7265",#Ranger, subset 1
    #"f7d408d7-5cd5-4214-b31c-ec8f75e197dc",# SVM, subset 3 <- issue, re-run
    #"e335d595-c095-4356-b967-d15c37479527",# ranger all
    #"b80328dd-9c40-4e99-8a9f-239121931fb4",# ranger subset 8
    #"f8ad4263-8470-43db-856b-4476dfc83ccc",# ranger subset 7
    #"1cd97e42-f7e1-4580-928b-1a42609a6549",# Ranger subset 5
    #"2b9d4a04-0586-4743-83ff-39e77a7345c7",#ranger subset 11
    #"6c3bedc5-11ae-423e-a858-13240650f14b",#RF-LDA substet 5
    #"f362ade9-43cd-4342-b62d-8f2f1d5c50b5",#RFLDA subset 9 <- this particular model returns all NAs???
    #"9c496675-d6b4-46d1-a3cc-4da9f69c702",# ranger subset 12, ~.4 <- wrong path
    #"rf_base",
    #"44e2506d-a587-4a27-acbb-1842f9fb421a",# SVM all
    #"02cdc9a4-2265-432b-8010-170048a94c01",# kNN, Subset 3
    #"7707394d-5755-4bf5-a8c9-e9f8d08e0aa8",# SVM, subset 4
    #"53bb89e1-22a9-4199-ac24-22232063dd79",# SVM subset 6
    #"cdb0d9c9-3f3e-4c3a-8277-336cc58fcaa8",# svm subset 7
    #"bef61c5e-9458-41df-9ce5-a30e45299e8f",# svm subset 10
    #"af392d97-067b-4391-8577-ead82f84fc08"#knn subset 12
    #"e335392b-73af-478d-a7f8-e3eaacea9774",#knn, subset 1 <- predictions failed, re-run
    ##"d41050ba-04b4-4507-a21e-d3743f59b793"
    #"5059eb96-fe79-43b7-bcc6-9dd54fbc3e83",
    #"654ae09e-666d-4eee-90a7-008b9b34b147",
    #"7920d1b5-4fc7-4ba0-b282-23fbecbc889a"

"31940dfa-a053-4398-b240-a33c768e5075"
)

#for(id in model_ids){
    id <- "rf_img_robust_min"
    model <- load_model(
        paste0("mle/models/gs/", id, ".rda")
    )

 

    save_path <- paste0("mle/experiments/gs/", id, "/")
    #print(names(model))
print(model)
    if(!dir.exists(save_path)){
        dir.create(save_path)
    }
    #print(quadrats[[3]])


   results <- validate_model(
       model, 
       save_path, 
       normalize_input = FALSE,
       standardize_input = FALSE,
       scale_input = FALSE,
       robust_scale_input = TRUE, 
       cluster = NULL)
   aggregated_results <- aggregate_results(save_path)

    plot_by_pft(
        aggregated_results,
        save_path = paste0(save_path, "aggregate.html"),
        open = FALSE
    )
#
    write_validation_table(
        aggregated_results,
        save_path = paste0(save_path, "table.html"),
        open = FALSE
    )

    
#}
# Out:
# Ranger result
#
# Call:
#  ranger::ranger(num.trees = 1024, importance = "impurity", classification = TRUE,      x = columnwise_robust_scale(test_data), y = test_labels)
#
# Type:                             Classification
# Number of trees:                  1024
# Sample size:                      248
# Number of independent variables:  214
# Mtry:                             14
# Target node size:                 1
# Variable importance mode:         impurity
# Splitrule:                        gini
# OOB prediction error:             11.29 %
# [1] "preprocessing raster at Data/Ground_Validation/Imagery/BisonGulchQuads.envi"
# [1] "Converted to Data frame?"
# [1] TRUE
# [1] "Noisy columns removed"
# [1] TRUE
# [1] "Filtered"
# [1] TRUE
# [1] "Imputing..."
# Using spline to predict value at new bands...
#
# Beware the spectra are now partially smoothed.
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# 0.004657 0.040281 0.079833 0.077252 0.111162 0.166569
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# 0.004364 0.039266 0.078478 0.076049 0.109991 0.169670
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# 0.004364 0.039266 0.078478 0.076049 0.109991 0.169670
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# 0.004364 0.039266 0.078478 0.076049 0.109991 0.169670
# [1] "Imputing..."
# `.cols` has been renamed and is deprecated, please use `.vars`
#        x              y            X397.593          X399.444
#  Min.   :-149   Min.   :63.81   Min.   :-1.0199   Min.   :-0.9250
#  1st Qu.:-149   1st Qu.:63.81   1st Qu.:-0.4323   1st Qu.:-0.4715
#  Median :-149   Median :63.81   Median : 0.0000   Median : 0.0000
#  Mean   :-149   Mean   :63.81   Mean   : 0.1151   Mean   : 0.0481
#  3rd Qu.:-149   3rd Qu.:63.81   3rd Qu.: 0.5677   3rd Qu.: 0.5285
#  Max.   :-149   Max.   :63.81   Max.   : 3.4763   Max.   : 2.1116
#     X401.296            X403.148             X405             X406.851
#  Min.   :-1.049083   Min.   :-1.18348   Min.   :-1.25635   Min.   :-1.26267
#  1st Qu.:-0.502961   1st Qu.:-0.60589   1st Qu.:-0.60723   1st Qu.:-0.59951
#  Median : 0.000000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   : 0.008998   Mean   :-0.08003   Mean   :-0.08523   Mean   :-0.07578
#  3rd Qu.: 0.497039   3rd Qu.: 0.39411   3rd Qu.: 0.39277   3rd Qu.: 0.40049
#  Max.   : 1.846751   Max.   : 1.67343   Max.   : 1.74903   Max.   : 1.55222
#     X408.703           X410.555          X412.407           X414.258
#  Min.   :-1.30519   Min.   :-1.3508   Min.   :-1.33611   Min.   :-1.37009
#  1st Qu.:-0.58682   1st Qu.:-0.5618   1st Qu.:-0.53963   1st Qu.:-0.56212
#  Median : 0.00000   Median : 0.0000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.06322   Mean   :-0.0568   Mean   :-0.04295   Mean   :-0.04884
#  3rd Qu.: 0.41318   3rd Qu.: 0.4382   3rd Qu.: 0.46037   3rd Qu.: 0.43788
#  Max.   : 1.88431   Max.   : 1.7099   Max.   : 1.93969   Max.   : 1.98439
#     X416.11            X417.962           X419.814           X421.666
#  Min.   :-1.36140   Min.   :-1.31923   Min.   :-1.29693   Min.   :-1.25634
#  1st Qu.:-0.55890   1st Qu.:-0.55867   1st Qu.:-0.55445   1st Qu.:-0.53425
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.04633   Mean   :-0.03864   Mean   :-0.03799   Mean   :-0.02923
#  3rd Qu.: 0.44110   3rd Qu.: 0.44133   3rd Qu.: 0.44555   3rd Qu.: 0.46575
#  Max.   : 1.87930   Max.   : 2.03872   Max.   : 1.89755   Max.   : 2.12994
#     X423.517           X425.369           X427.221           X429.073
#  Min.   :-1.26840   Min.   :-1.29973   Min.   :-1.27520   Min.   :-1.29360
#  1st Qu.:-0.53926   1st Qu.:-0.53347   1st Qu.:-0.53565   1st Qu.:-0.53322
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.03827   Mean   :-0.02977   Mean   :-0.02673   Mean   :-0.02489
#  3rd Qu.: 0.46074   3rd Qu.: 0.46653   3rd Qu.: 0.46435   3rd Qu.: 0.46678
#  Max.   : 2.11741   Max.   : 2.09851   Max.   : 2.13112   Max.   : 2.28830
#     X430.924           X432.776           X434.628           X436.48
#  Min.   :-1.27021   Min.   :-1.27315   Min.   :-1.26693   Min.   :-1.27757
#  1st Qu.:-0.53902   1st Qu.:-0.55150   1st Qu.:-0.55215   1st Qu.:-0.54878
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.02673   Mean   :-0.04346   Mean   :-0.04269   Mean   :-0.03837
#  3rd Qu.: 0.46098   3rd Qu.: 0.44850   3rd Qu.: 0.44785   3rd Qu.: 0.45122
#  Max.   : 2.00413   Max.   : 2.01853   Max.   : 2.06609   Max.   : 1.93353
#     X438.332          X440.183           X442.035           X443.887
#  Min.   :-1.2363   Min.   :-1.20449   Min.   :-1.22939   Min.   :-1.169393
#  1st Qu.:-0.5424   1st Qu.:-0.52714   1st Qu.:-0.53155   1st Qu.:-0.514184
#  Median : 0.0000   Median : 0.00000   Median : 0.00000   Median : 0.000000
#  Mean   :-0.0316   Mean   :-0.02342   Mean   :-0.02203   Mean   :-0.009883
#  3rd Qu.: 0.4576   3rd Qu.: 0.47286   3rd Qu.: 0.46845   3rd Qu.: 0.485816
#  Max.   : 2.1782   Max.   : 2.08715   Max.   : 1.99298   Max.   : 2.002910
#     X445.739           X447.59            X449.442           X451.294
#  Min.   :-1.22585   Min.   :-1.16864   Min.   :-1.23671   Min.   :-1.17027
#  1st Qu.:-0.52845   1st Qu.:-0.53286   1st Qu.:-0.53242   1st Qu.:-0.54263
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.01713   Mean   :-0.02493   Mean   :-0.02895   Mean   :-0.03569
#  3rd Qu.: 0.47155   3rd Qu.: 0.46714   3rd Qu.: 0.46758   3rd Qu.: 0.45737
#  Max.   : 2.01802   Max.   : 2.04856   Max.   : 2.07620   Max.   : 2.06115
#     X453.146           X454.998           X456.849          X458.701
#  Min.   :-1.15704   Min.   :-1.19702   Min.   :-1.1660   Min.   :-1.21384
#  1st Qu.:-0.53193   1st Qu.:-0.54161   1st Qu.:-0.5341   1st Qu.:-0.52966
#  Median : 0.00000   Median : 0.00000   Median : 0.0000   Median : 0.00000
#  Mean   :-0.02672   Mean   :-0.03235   Mean   :-0.0305   Mean   :-0.02317
#  3rd Qu.: 0.46807   3rd Qu.: 0.45839   3rd Qu.: 0.4659   3rd Qu.: 0.47034
#  Max.   : 2.01131   Max.   : 2.07619   Max.   : 2.0529   Max.   : 2.09627
#     X460.553           X462.405           X464.256           X466.108
#  Min.   :-1.20220   Min.   :-1.16962   Min.   :-1.18990   Min.   :-1.18690
#  1st Qu.:-0.53640   1st Qu.:-0.53026   1st Qu.:-0.54196   1st Qu.:-0.54352
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.03185   Mean   :-0.02782   Mean   :-0.03487   Mean   :-0.03688
#  3rd Qu.: 0.46360   3rd Qu.: 0.46974   3rd Qu.: 0.45804   3rd Qu.: 0.45648
#  Max.   : 2.11125   Max.   : 2.02501   Max.   : 2.11992   Max.   : 2.17298
#     X467.96            X469.812           X471.664           X473.515
#  Min.   :-1.19134   Min.   :-1.18114   Min.   :-1.23141   Min.   :-1.1721
#  1st Qu.:-0.54206   1st Qu.:-0.53804   1st Qu.:-0.53988   1st Qu.:-0.5463
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.0000
#  Mean   :-0.03501   Mean   :-0.02935   Mean   :-0.03489   Mean   :-0.0361
#  3rd Qu.: 0.45794   3rd Qu.: 0.46196   3rd Qu.: 0.46012   3rd Qu.: 0.4537
#  Max.   : 2.02576   Max.   : 2.03803   Max.   : 2.14312   Max.   : 2.1156
#     X475.367           X477.219           X479.071           X480.922
#  Min.   :-1.14812   Min.   :-1.16775   Min.   :-1.17495   Min.   :-1.14784
#  1st Qu.:-0.54979   1st Qu.:-0.54264   1st Qu.:-0.53465   1st Qu.:-0.54000
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.03846   Mean   :-0.03488   Mean   :-0.03208   Mean   :-0.03318
#  3rd Qu.: 0.45021   3rd Qu.: 0.45736   3rd Qu.: 0.46535   3rd Qu.: 0.46000
#  Max.   : 2.10915   Max.   : 2.14056   Max.   : 2.00412   Max.   : 2.14954
#     X482.774           X484.626           X486.478           X488.33
#  Min.   :-1.15957   Min.   :-1.18606   Min.   :-1.16025   Min.   :-1.13363
#  1st Qu.:-0.53481   1st Qu.:-0.54104   1st Qu.:-0.53556   1st Qu.:-0.53234
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.02669   Mean   :-0.03209   Mean   :-0.02481   Mean   :-0.02633
#  3rd Qu.: 0.46519   3rd Qu.: 0.45896   3rd Qu.: 0.46444   3rd Qu.: 0.46766
#  Max.   : 2.14737   Max.   : 2.13222   Max.   : 2.14994   Max.   : 2.05536
#     X490.181           X492.033           X493.885           X495.737
#  Min.   :-1.19979   Min.   :-1.14745   Min.   :-1.14428   Min.   :-1.16259
#  1st Qu.:-0.52993   1st Qu.:-0.53152   1st Qu.:-0.53034   1st Qu.:-0.53147
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.02342   Mean   :-0.02608   Mean   :-0.02776   Mean   :-0.02484
#  3rd Qu.: 0.47007   3rd Qu.: 0.46848   3rd Qu.: 0.46966   3rd Qu.: 0.46853
#  Max.   : 2.04138   Max.   : 2.16123   Max.   : 2.05708   Max.   : 2.09730
#     X497.588           X499.44            X501.292           X503.144
#  Min.   :-1.17944   Min.   :-1.20644   Min.   :-1.18126   Min.   :-1.18030
#  1st Qu.:-0.53501   1st Qu.:-0.52671   1st Qu.:-0.52357   1st Qu.:-0.52423
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.02878   Mean   :-0.02195   Mean   :-0.02261   Mean   :-0.02269
#  3rd Qu.: 0.46499   3rd Qu.: 0.47329   3rd Qu.: 0.47643   3rd Qu.: 0.47577
#  Max.   : 2.02481   Max.   : 2.16722   Max.   : 2.08107   Max.   : 2.13844
#     X504.996           X506.847           X508.699           X510.551
#  Min.   :-1.18770   Min.   :-1.21160   Min.   :-1.25172   Min.   :-1.2094
#  1st Qu.:-0.52773   1st Qu.:-0.52504   1st Qu.:-0.51440   1st Qu.:-0.5106
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.0000
#  Mean   :-0.02249   Mean   :-0.02373   Mean   :-0.01861   Mean   :-0.0181
#  3rd Qu.: 0.47227   3rd Qu.: 0.47496   3rd Qu.: 0.48560   3rd Qu.: 0.4894
#  Max.   : 2.13535   Max.   : 2.06328   Max.   : 2.20088   Max.   : 2.1266
#     X512.403           X514.254          X516.106           X517.958
#  Min.   :-1.26871   Min.   :-1.2925   Min.   :-1.33754   Min.   :-1.34421
#  1st Qu.:-0.51480   1st Qu.:-0.5044   1st Qu.:-0.50845   1st Qu.:-0.50280
#  Median : 0.00000   Median : 0.0000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.02652   Mean   :-0.0141   Mean   :-0.01764   Mean   :-0.01739
#  3rd Qu.: 0.48520   3rd Qu.: 0.4956   3rd Qu.: 0.49155   3rd Qu.: 0.49720
#  Max.   : 2.17133   Max.   : 2.1746   Max.   : 2.23706   Max.   : 2.18043
#     X519.81            X521.662           X523.513            X525.365
#  Min.   :-1.35971   Min.   :-1.37342   Min.   :-1.499938   Min.   :-1.478251
#  1st Qu.:-0.49327   1st Qu.:-0.48700   1st Qu.:-0.481563   1st Qu.:-0.465314
#  Median : 0.00000   Median : 0.00000   Median : 0.000000   Median : 0.000000
#  Mean   :-0.01048   Mean   :-0.01042   Mean   :-0.008449   Mean   : 0.000845
#  3rd Qu.: 0.50673   3rd Qu.: 0.51300   3rd Qu.: 0.518437   3rd Qu.: 0.534686
#  Max.   : 2.20958   Max.   : 2.16224   Max.   : 2.303363   Max.   : 2.439528
#     X527.217            X529.069           X530.92
#  Min.   :-1.540164   Min.   :-1.71775   Min.   :-1.687328
#  1st Qu.:-0.458828   1st Qu.:-0.45027   1st Qu.:-0.453325
#  Median : 0.000000   Median : 0.00000   Median : 0.000000
#  Mean   : 0.003194   Mean   : 0.01085   Mean   : 0.004668
#  3rd Qu.: 0.541172   3rd Qu.: 0.54973   3rd Qu.: 0.546675
#  Max.   : 2.462020   Max.   : 2.39672   Max.   : 2.473063
#     X532.772             X534.624             X536.476
#  Min.   :-1.7122912   Min.   :-1.7593890   Min.   :-1.703202
#  1st Qu.:-0.4543735   1st Qu.:-0.4520186   1st Qu.:-0.443676
#  Median : 0.0000000   Median : 0.0000000   Median : 0.000000
#  Mean   : 0.0000305   Mean   : 0.0006364   Mean   : 0.001678
#  3rd Qu.: 0.5456265   3rd Qu.: 0.5479814   3rd Qu.: 0.556324
#  Max.   : 2.5845665   Max.   : 2.5014071   Max.   : 2.476803
#     X538.328            X540.179            X542.031
#  Min.   :-1.760302   Min.   :-1.710814   Min.   :-1.850247
#  1st Qu.:-0.436791   1st Qu.:-0.437171   1st Qu.:-0.452631
#  Median : 0.000000   Median : 0.000000   Median : 0.000000
#  Mean   : 0.007083   Mean   : 0.004183   Mean   :-0.008442
#  3rd Qu.: 0.563209   3rd Qu.: 0.562829   3rd Qu.: 0.547369
#  Max.   : 2.599051   Max.   : 2.393703   Max.   : 2.426089
#     X543.883            X545.735            X547.586
#  Min.   :-1.797519   Min.   :-1.839079   Min.   :-1.8167896
#  1st Qu.:-0.437675   1st Qu.:-0.435827   1st Qu.:-0.4391992
#  Median : 0.000000   Median : 0.000000   Median : 0.0000000
#  Mean   :-0.001201   Mean   : 0.005685   Mean   : 0.0002323
#  3rd Qu.: 0.562325   3rd Qu.: 0.564173   3rd Qu.: 0.5608008
#  Max.   : 2.427107   Max.   : 2.405785   Max.   : 2.3962892
#     X549.438             X551.29             X553.142
#  Min.   :-1.7994133   Min.   :-1.825439   Min.   :-1.8821304
#  1st Qu.:-0.4467783   1st Qu.:-0.443723   1st Qu.:-0.4410269
#  Median : 0.0000000   Median : 0.000000   Median : 0.0000000
#  Mean   : 0.0003816   Mean   :-0.004168   Mean   :-0.0003539
#  3rd Qu.: 0.5532217   3rd Qu.: 0.556277   3rd Qu.: 0.5589731
#  Max.   : 2.3949133   Max.   : 2.325796   Max.   : 2.3536646
#     X554.994            X556.845            X558.697
#  Min.   :-1.920559   Min.   :-1.789546   Min.   :-1.808548
#  1st Qu.:-0.440951   1st Qu.:-0.439627   1st Qu.:-0.446512
#  Median : 0.000000   Median : 0.000000   Median : 0.000000
#  Mean   :-0.001636   Mean   :-0.003906   Mean   :-0.001296
#  3rd Qu.: 0.559049   3rd Qu.: 0.560373   3rd Qu.: 0.553488
#  Max.   : 2.308320   Max.   : 2.291355   Max.   : 2.299575
#     X560.549            X562.401           X564.252           X566.104
#  Min.   :-1.769069   Min.   :-1.75837   Min.   :-1.75864   Min.   :-1.7208
#  1st Qu.:-0.434679   1st Qu.:-0.42823   1st Qu.:-0.42659   1st Qu.:-0.4371
#  Median : 0.000000   Median : 0.00000   Median : 0.00000   Median : 0.0000
#  Mean   : 0.003439   Mean   : 0.01476   Mean   : 0.01854   Mean   : 0.0072
#  3rd Qu.: 0.565321   3rd Qu.: 0.57177   3rd Qu.: 0.57341   3rd Qu.: 0.5629
#  Max.   : 2.315924   Max.   : 2.23786   Max.   : 2.22329   Max.   : 2.1249
#     X567.956            X569.808          X571.659            X573.511
#  Min.   :-1.777871   Min.   :-1.6898   Min.   :-1.615086   Min.   :-1.578802
#  1st Qu.:-0.436747   1st Qu.:-0.4324   1st Qu.:-0.449353   1st Qu.:-0.439320
#  Median : 0.000000   Median : 0.0000   Median : 0.000000   Median : 0.000000
#  Mean   : 0.009096   Mean   : 0.0148   Mean   : 0.005439   Mean   : 0.007106
#  3rd Qu.: 0.563253   3rd Qu.: 0.5676   3rd Qu.: 0.550647   3rd Qu.: 0.560680
#  Max.   : 2.139998   Max.   : 2.0718   Max.   : 2.040046   Max.   : 1.984221
#     X575.363           X577.215            X579.067            X580.918
#  Min.   :-1.56006   Min.   :-1.558359   Min.   :-1.505282   Min.   :-1.51321
#  1st Qu.:-0.44470   1st Qu.:-0.441997   1st Qu.:-0.455878   1st Qu.:-0.44572
#  Median : 0.00000   Median : 0.000000   Median : 0.000000   Median : 0.00000
#  Mean   : 0.01232   Mean   : 0.009475   Mean   : 0.006152   Mean   : 0.01265
#  3rd Qu.: 0.55530   3rd Qu.: 0.558003   3rd Qu.: 0.544122   3rd Qu.: 0.55428
#  Max.   : 1.98815   Max.   : 1.927185   Max.   : 1.878259   Max.   : 1.86071
#     X582.77            X584.622            X586.474           X588.325
#  Min.   :-1.49305   Min.   :-1.456873   Min.   :-1.41707   Min.   :-1.422646
#  1st Qu.:-0.45086   1st Qu.:-0.455540   1st Qu.:-0.45363   1st Qu.:-0.454645
#  Median : 0.00000   Median : 0.000000   Median : 0.00000   Median : 0.000000
#  Mean   : 0.01417   Mean   : 0.009989   Mean   : 0.01405   Mean   : 0.007593
#  3rd Qu.: 0.54914   3rd Qu.: 0.544460   3rd Qu.: 0.54637   3rd Qu.: 0.545354
#  Max.   : 1.78759   Max.   : 1.814584   Max.   : 1.85460   Max.   : 2.073878
#     X590.177            X592.029            X593.881           X595.733
#  Min.   :-1.441447   Min.   :-1.380158   Min.   :-1.42937   Min.   :-1.34469
#  1st Qu.:-0.469595   1st Qu.:-0.461860   1st Qu.:-0.45260   1st Qu.:-0.47363
#  Median : 0.000000   Median : 0.000000   Median : 0.00000   Median : 0.00000
#  Mean   : 0.001421   Mean   : 0.009255   Mean   : 0.01562   Mean   : 0.00225
#  3rd Qu.: 0.530404   3rd Qu.: 0.538140   3rd Qu.: 0.54740   3rd Qu.: 0.52637
#  Max.   : 2.254771   Max.   : 2.397058   Max.   : 2.53904   Max.   : 2.68622
#     X597.584            X599.436            X601.288
#  Min.   :-1.431856   Min.   :-1.377867   Min.   :-1.4539013
#  1st Qu.:-0.467763   1st Qu.:-0.466655   1st Qu.:-0.4735749
#  Median : 0.000000   Median : 0.000000   Median : 0.0000000
#  Mean   : 0.002995   Mean   : 0.004885   Mean   : 0.0004601
#  3rd Qu.: 0.532237   3rd Qu.: 0.533345   3rd Qu.: 0.5264251
#  Max.   : 2.697008   Max.   : 2.812676   Max.   : 2.8947632
#     X603.14              X604.991           X606.843
#  Min.   :-1.4257927   Min.   :-1.39172   Min.   :-1.4070161
#  1st Qu.:-0.4753920   1st Qu.:-0.47362   1st Qu.:-0.4784656
#  Median : 0.0000000   Median : 0.00000   Median : 0.0000000
#  Mean   : 0.0002947   Mean   : 0.00103   Mean   : 0.0005454
#  3rd Qu.: 0.5246080   3rd Qu.: 0.52638   3rd Qu.: 0.5215344
#  Max.   : 2.9511488   Max.   : 2.87714   Max.   : 2.8298433
#     X608.695            X610.547            X612.399            X614.25
#  Min.   :-1.403105   Min.   :-1.405695   Min.   :-1.394569   Min.   :-1.35048
#  1st Qu.:-0.471423   1st Qu.:-0.479963   1st Qu.:-0.483665   1st Qu.:-0.48366
#  Median : 0.000000   Median : 0.000000   Median : 0.000000   Median : 0.00000
#  Mean   : 0.001399   Mean   :-0.002013   Mean   :-0.002213   Mean   :-0.00306
#  3rd Qu.: 0.528577   3rd Qu.: 0.520037   3rd Qu.: 0.516335   3rd Qu.: 0.51634
#  Max.   : 2.873582   Max.   : 3.104088   Max.   : 2.820808   Max.   : 2.75289
#     X616.102            X617.954            X619.806
#  Min.   :-1.282163   Min.   :-1.324346   Min.   :-1.310586
#  1st Qu.:-0.493467   1st Qu.:-0.489005   1st Qu.:-0.493318
#  Median : 0.000000   Median : 0.000000   Median : 0.000000
#  Mean   :-0.005666   Mean   :-0.001075   Mean   :-0.007772
#  3rd Qu.: 0.506533   3rd Qu.: 0.510995   3rd Qu.: 0.506682
#  Max.   : 2.767964   Max.   : 2.709013   Max.   : 2.658981
#     X621.657            X623.509            X625.361          X627.213
#  Min.   :-1.360981   Min.   :-1.300479   Min.   :-1.3229   Min.   :-1.33590
#  1st Qu.:-0.498881   1st Qu.:-0.496411   1st Qu.:-0.4972   1st Qu.:-0.51023
#  Median : 0.000000   Median : 0.000000   Median : 0.0000   Median : 0.00000
#  Mean   :-0.007067   Mean   :-0.008679   Mean   :-0.0108   Mean   :-0.01886
#  3rd Qu.: 0.501119   3rd Qu.: 0.503589   3rd Qu.: 0.5028   3rd Qu.: 0.48977
#  Max.   : 2.606800   Max.   : 2.709478   Max.   : 2.5075   Max.   : 2.49183
#     X629.065           X630.916           X632.768           X634.62
#  Min.   :-1.33239   Min.   :-1.33420   Min.   :-1.30608   Min.   :-1.31293
#  1st Qu.:-0.49737   1st Qu.:-0.50597   1st Qu.:-0.50312   1st Qu.:-0.50137
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.01301   Mean   :-0.01502   Mean   :-0.01397   Mean   :-0.02075
#  3rd Qu.: 0.50263   3rd Qu.: 0.49403   3rd Qu.: 0.49688   3rd Qu.: 0.49863
#  Max.   : 2.47742   Max.   : 2.49656   Max.   : 2.43946   Max.   : 2.26137
#     X636.472          X638.323           X640.175           X642.027
#  Min.   :-1.3597   Min.   :-1.29777   Min.   :-1.30983   Min.   :-1.27370
#  1st Qu.:-0.5122   1st Qu.:-0.50737   1st Qu.:-0.50863   1st Qu.:-0.52029
#  Median : 0.0000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.0199   Mean   :-0.01848   Mean   :-0.02458   Mean   :-0.02322
#  3rd Qu.: 0.4878   3rd Qu.: 0.49263   3rd Qu.: 0.49137   3rd Qu.: 0.47971
#  Max.   : 2.3386   Max.   : 2.19988   Max.   : 2.15462   Max.   : 2.00424
#     X643.879           X645.731           X647.582           X649.434
#  Min.   :-1.26551   Min.   :-1.26046   Min.   :-1.28589   Min.   :-1.24928
#  1st Qu.:-0.52448   1st Qu.:-0.52862   1st Qu.:-0.54133   1st Qu.:-0.52534
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.02709   Mean   :-0.02566   Mean   :-0.03746   Mean   :-0.02773
#  3rd Qu.: 0.47552   3rd Qu.: 0.47138   3rd Qu.: 0.45867   3rd Qu.: 0.47466
#  Max.   : 2.06689   Max.   : 1.93738   Max.   : 2.01702   Max.   : 1.81277
#     X651.286           X653.138           X654.989           X656.841
#  Min.   :-1.21652   Min.   :-1.25786   Min.   :-1.20378   Min.   :-1.20902
#  1st Qu.:-0.53623   1st Qu.:-0.53029   1st Qu.:-0.53073   1st Qu.:-0.53738
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.03255   Mean   :-0.02987   Mean   :-0.02892   Mean   :-0.02747
#  3rd Qu.: 0.46377   3rd Qu.: 0.46971   3rd Qu.: 0.46927   3rd Qu.: 0.46262
#  Max.   : 1.75926   Max.   : 1.85495   Max.   : 1.71739   Max.   : 1.65568
#     X658.693          X660.545           X662.397           X664.248
#  Min.   :-1.2032   Min.   :-1.20945   Min.   :-1.18716   Min.   :-1.16932
#  1st Qu.:-0.5426   1st Qu.:-0.53711   1st Qu.:-0.54716   1st Qu.:-0.54586
#  Median : 0.0000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.0341   Mean   :-0.03163   Mean   :-0.03524   Mean   :-0.03311
#  3rd Qu.: 0.4574   3rd Qu.: 0.46289   3rd Qu.: 0.45284   3rd Qu.: 0.45414
#  Max.   : 1.5913   Max.   : 1.63050   Max.   : 1.45826   Max.   : 1.48867
#      X666.1            X667.952           X669.804          X671.655
#  Min.   :-1.18732   Min.   :-1.15986   Min.   :-1.1545   Min.   :-1.14473
#  1st Qu.:-0.54886   1st Qu.:-0.54692   1st Qu.:-0.5466   1st Qu.:-0.53768
#  Median : 0.00000   Median : 0.00000   Median : 0.0000   Median : 0.00000
#  Mean   :-0.03567   Mean   :-0.03475   Mean   :-0.0297   Mean   :-0.02504
#  3rd Qu.: 0.45114   3rd Qu.: 0.45308   3rd Qu.: 0.4534   3rd Qu.: 0.46232
#  Max.   : 1.38110   Max.   : 1.41079   Max.   : 1.4421   Max.   : 1.39695
#     X673.507           X675.359           X677.211           X679.063
#  Min.   :-1.15401   Min.   :-1.14185   Min.   :-1.14323   Min.   :-1.15316
#  1st Qu.:-0.54507   1st Qu.:-0.54826   1st Qu.:-0.54594   1st Qu.:-0.55355
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.03075   Mean   :-0.03283   Mean   :-0.02936   Mean   :-0.03644
#  3rd Qu.: 0.45493   3rd Qu.: 0.45174   3rd Qu.: 0.45406   3rd Qu.: 0.44645
#  Max.   : 1.28642   Max.   : 1.32969   Max.   : 1.42090   Max.   : 1.37689
#     X680.914           X682.766           X684.618           X686.47
#  Min.   :-1.16749   Min.   :-1.16385   Min.   :-1.18276   Min.   :-1.19802
#  1st Qu.:-0.54555   1st Qu.:-0.55566   1st Qu.:-0.55160   1st Qu.:-0.53891
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.03426   Mean   :-0.03777   Mean   :-0.03966   Mean   :-0.02908
#  3rd Qu.: 0.45445   3rd Qu.: 0.44434   3rd Qu.: 0.44840   3rd Qu.: 0.46109
#  Max.   : 1.32938   Max.   : 1.26822   Max.   : 1.28601   Max.   : 1.50380
#     X688.321           X690.173           X692.025           X693.877
#  Min.   :-1.25380   Min.   :-1.29567   Min.   :-1.37761   Min.   :-1.4396
#  1st Qu.:-0.52887   1st Qu.:-0.52752   1st Qu.:-0.50957   1st Qu.:-0.5246
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.0000
#  Mean   :-0.03202   Mean   :-0.03387   Mean   :-0.02834   Mean   :-0.0449
#  3rd Qu.: 0.47113   3rd Qu.: 0.47248   3rd Qu.: 0.49043   3rd Qu.: 0.4754
#  Max.   : 1.39147   Max.   : 1.44347   Max.   : 1.51818   Max.   : 1.6836
#     X695.729           X697.58            X699.432           X701.284
#  Min.   :-1.53735   Min.   :-1.68607   Min.   :-1.95988   Min.   :-2.15393
#  1st Qu.:-0.51814   1st Qu.:-0.52759   1st Qu.:-0.52053   1st Qu.:-0.50685
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.03968   Mean   :-0.06323   Mean   :-0.06801   Mean   :-0.08454
#  3rd Qu.: 0.48186   3rd Qu.: 0.47241   3rd Qu.: 0.47947   3rd Qu.: 0.49315
#  Max.   : 1.64375   Max.   : 1.79254   Max.   : 1.83938   Max.   : 2.30107
#     X703.136          X704.987          X706.839          X708.691
#  Min.   :-2.4651   Min.   :-2.6940   Min.   :-3.1008   Min.   :-3.2715
#  1st Qu.:-0.5241   1st Qu.:-0.5296   1st Qu.:-0.5462   1st Qu.:-0.5676
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   :-0.1116   Mean   :-0.1321   Mean   :-0.1632   Mean   :-0.1900
#  3rd Qu.: 0.4759   3rd Qu.: 0.4704   3rd Qu.: 0.4538   3rd Qu.: 0.4324
#  Max.   : 1.9530   Max.   : 2.3975   Max.   : 2.7101   Max.   : 3.0206
#     X710.543          X712.395          X714.246          X716.098
#  Min.   :-3.2656   Min.   :-3.2120   Min.   :-3.2395   Min.   :-3.2225
#  1st Qu.:-0.5889   1st Qu.:-0.6039   1st Qu.:-0.6062   1st Qu.:-0.6020
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   :-0.2095   Mean   :-0.2090   Mean   :-0.2000   Mean   :-0.1804
#  3rd Qu.: 0.4111   3rd Qu.: 0.3961   3rd Qu.: 0.3938   3rd Qu.: 0.3980
#  Max.   : 2.9227   Max.   : 3.2040   Max.   : 3.3150   Max.   : 3.3886
#     X717.95           X719.802          X721.653           X723.505
#  Min.   :-3.3229   Min.   :-3.1858   Min.   :-3.05312   Min.   :-2.84357
#  1st Qu.:-0.5816   1st Qu.:-0.5795   1st Qu.:-0.57583   1st Qu.:-0.55238
#  Median : 0.0000   Median : 0.0000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.1373   Mean   :-0.1030   Mean   :-0.07097   Mean   :-0.02622
#  3rd Qu.: 0.4184   3rd Qu.: 0.4205   3rd Qu.: 0.42417   3rd Qu.: 0.44762
#  Max.   : 3.6535   Max.   : 3.3065   Max.   : 3.48128   Max.   : 3.49213
#     X725.357           X727.209           X729.061           X730.912
#  Min.   :-2.76444   Min.   :-2.65490   Min.   :-2.60511   Min.   :-2.6159
#  1st Qu.:-0.52599   1st Qu.:-0.48189   1st Qu.:-0.47374   1st Qu.:-0.4479
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.0000
#  Mean   : 0.01408   Mean   : 0.06524   Mean   : 0.08916   Mean   : 0.1238
#  3rd Qu.: 0.47401   3rd Qu.: 0.51811   3rd Qu.: 0.52626   3rd Qu.: 0.5521
#  Max.   : 3.80750   Max.   : 3.77744   Max.   : 3.71878   Max.   : 3.8215
#     X732.764          X734.616          X736.468          X738.319
#  Min.   :-2.3801   Min.   :-2.4686   Min.   :-2.2307   Min.   :-2.0927
#  1st Qu.:-0.4390   1st Qu.:-0.4129   1st Qu.:-0.4128   1st Qu.:-0.3869
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.1432   Mean   : 0.1734   Mean   : 0.1886   Mean   : 0.2121
#  3rd Qu.: 0.5610   3rd Qu.: 0.5871   3rd Qu.: 0.5872   3rd Qu.: 0.6131
#  Max.   : 3.9161   Max.   : 3.8313   Max.   : 3.9077   Max.   : 3.9962
#     X740.171          X742.023          X743.875          X745.726
#  Min.   :-2.0085   Min.   :-2.0153   Min.   :-1.9207   Min.   :-2.0579
#  1st Qu.:-0.3850   1st Qu.:-0.3852   1st Qu.:-0.3633   1st Qu.:-0.3730
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2186   Mean   : 0.2276   Mean   : 0.2435   Mean   : 0.2496
#  3rd Qu.: 0.6150   3rd Qu.: 0.6148   3rd Qu.: 0.6367   3rd Qu.: 0.6270
#  Max.   : 3.8304   Max.   : 4.0376   Max.   : 3.8942   Max.   : 3.9410
#     X747.578          X749.43           X751.282          X753.134
#  Min.   :-1.9844   Min.   :-1.8949   Min.   :-1.8784   Min.   :-1.9190
#  1st Qu.:-0.3584   1st Qu.:-0.3646   1st Qu.:-0.3565   1st Qu.:-0.3589
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2508   Mean   : 0.2569   Mean   : 0.2670   Mean   : 0.2561
#  3rd Qu.: 0.6416   3rd Qu.: 0.6354   3rd Qu.: 0.6435   3rd Qu.: 0.6411
#  Max.   : 3.9087   Max.   : 3.9010   Max.   : 4.0602   Max.   : 3.9847
#     X754.985          X756.837          X758.689          X760.541
#  Min.   :-1.9513   Min.   :-1.8191   Min.   :-1.8686   Min.   :-1.9668
#  1st Qu.:-0.3553   1st Qu.:-0.3697   1st Qu.:-0.3602   1st Qu.:-0.3833
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2625   Mean   : 0.2581   Mean   : 0.2563   Mean   : 0.2415
#  3rd Qu.: 0.6447   3rd Qu.: 0.6303   3rd Qu.: 0.6398   3rd Qu.: 0.6167
#  Max.   : 3.8864   Max.   : 4.0657   Max.   : 4.0105   Max.   : 3.8782
#     X762.392          X764.244          X766.096          X767.948
#  Min.   :-2.0147   Min.   :-2.1343   Min.   :-1.9416   Min.   :-1.9396
#  1st Qu.:-0.3695   1st Qu.:-0.3680   1st Qu.:-0.3353   1st Qu.:-0.3719
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2564   Mean   : 0.2499   Mean   : 0.2713   Mean   : 0.2510
#  3rd Qu.: 0.6305   3rd Qu.: 0.6320   3rd Qu.: 0.6647   3rd Qu.: 0.6281
#  Max.   : 4.2407   Max.   : 4.1477   Max.   : 4.2110   Max.   : 3.7807
#      X769.8           X771.651          X773.503          X775.355
#  Min.   :-1.7830   Min.   :-1.8704   Min.   :-1.7615   Min.   :-1.8664
#  1st Qu.:-0.3571   1st Qu.:-0.3629   1st Qu.:-0.3790   1st Qu.:-0.3697
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2567   Mean   : 0.2607   Mean   : 0.2616   Mean   : 0.2544
#  3rd Qu.: 0.6429   3rd Qu.: 0.6371   3rd Qu.: 0.6210   3rd Qu.: 0.6303
#  Max.   : 4.0726   Max.   : 4.0052   Max.   : 4.0179   Max.   : 3.8734
#     X777.207          X779.058          X780.91           X782.762
#  Min.   :-1.7496   Min.   :-1.8772   Min.   :-1.6672   Min.   :-1.7551
#  1st Qu.:-0.3624   1st Qu.:-0.3393   1st Qu.:-0.3559   1st Qu.:-0.3557
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2635   Mean   : 0.2811   Mean   : 0.2564   Mean   : 0.2573
#  3rd Qu.: 0.6376   3rd Qu.: 0.6607   3rd Qu.: 0.6441   3rd Qu.: 0.6443
#  Max.   : 4.1036   Max.   : 3.9465   Max.   : 3.8795   Max.   : 3.8997
#     X784.614          X786.466          X788.317          X790.169
#  Min.   :-1.6575   Min.   :-1.7773   Min.   :-1.7199   Min.   :-1.7212
#  1st Qu.:-0.3674   1st Qu.:-0.3800   1st Qu.:-0.3627   1st Qu.:-0.3709
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2655   Mean   : 0.2579   Mean   : 0.2695   Mean   : 0.2586
#  3rd Qu.: 0.6326   3rd Qu.: 0.6200   3rd Qu.: 0.6373   3rd Qu.: 0.6291
#  Max.   : 4.2017   Max.   : 4.0067   Max.   : 4.0114   Max.   : 3.9319
#     X792.021          X793.873          X795.724          X797.576
#  Min.   :-1.7813   Min.   :-1.6911   Min.   :-1.6615   Min.   :-1.6833
#  1st Qu.:-0.3637   1st Qu.:-0.3608   1st Qu.:-0.3454   1st Qu.:-0.3603
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2666   Mean   : 0.2566   Mean   : 0.2806   Mean   : 0.2613
#  3rd Qu.: 0.6363   3rd Qu.: 0.6392   3rd Qu.: 0.6546   3rd Qu.: 0.6397
#  Max.   : 4.0584   Max.   : 3.7945   Max.   : 3.9076   Max.   : 3.8612
#     X799.428          X801.28           X803.132          X804.983
#  Min.   :-1.7000   Min.   :-1.6776   Min.   :-1.6680   Min.   :-1.7803
#  1st Qu.:-0.3447   1st Qu.:-0.3341   1st Qu.:-0.3531   1st Qu.:-0.3544
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2767   Mean   : 0.2844   Mean   : 0.2675   Mean   : 0.2680
#  3rd Qu.: 0.6553   3rd Qu.: 0.6659   3rd Qu.: 0.6469   3rd Qu.: 0.6456
#  Max.   : 4.0003   Max.   : 4.0814   Max.   : 4.3484   Max.   : 3.9158
#     X806.835          X808.687          X810.539          X812.39
#  Min.   :-1.8595   Min.   :-1.7623   Min.   :-1.7307   Min.   :-1.8752
#  1st Qu.:-0.3663   1st Qu.:-0.3572   1st Qu.:-0.3564   1st Qu.:-0.3632
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2594   Mean   : 0.2580   Mean   : 0.2653   Mean   : 0.2682
#  3rd Qu.: 0.6337   3rd Qu.: 0.6428   3rd Qu.: 0.6436   3rd Qu.: 0.6368
#  Max.   : 3.9351   Max.   : 3.8574   Max.   : 3.9177   Max.   : 4.3147
#     X814.242          X816.094          X817.946          X819.798
#  Min.   :-2.1160   Min.   :-2.0273   Min.   :-1.9581   Min.   :-2.0425
#  1st Qu.:-0.3680   1st Qu.:-0.4013   1st Qu.:-0.4140   1st Qu.:-0.3968
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2502   Mean   : 0.2361   Mean   : 0.2163   Mean   : 0.2265
#  3rd Qu.: 0.6320   3rd Qu.: 0.5987   3rd Qu.: 0.5860   3rd Qu.: 0.6032
#  Max.   : 4.2733   Max.   : 4.2176   Max.   : 4.3132   Max.   : 4.2508
#     X821.649          X823.501          X825.353          X827.205
#  Min.   :-1.9246   Min.   :-1.7098   Min.   :-1.9224   Min.   :-1.8824
#  1st Qu.:-0.4032   1st Qu.:-0.4090   1st Qu.:-0.3912   1st Qu.:-0.3881
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2218   Mean   : 0.2127   Mean   : 0.2132   Mean   : 0.2206
#  3rd Qu.: 0.5968   3rd Qu.: 0.5910   3rd Qu.: 0.6088   3rd Qu.: 0.6119
#  Max.   : 4.0451   Max.   : 3.9739   Max.   : 3.8637   Max.   : 3.8034
#     X829.056          X830.908          X832.76           X834.612
#  Min.   :-2.1197   Min.   :-1.8765   Min.   :-1.8853   Min.   :-1.6403
#  1st Qu.:-0.4130   1st Qu.:-0.3620   1st Qu.:-0.3730   1st Qu.:-0.3603
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2043   Mean   : 0.2391   Mean   : 0.2307   Mean   : 0.2440
#  3rd Qu.: 0.5870   3rd Qu.: 0.6380   3rd Qu.: 0.6270   3rd Qu.: 0.6397
#  Max.   : 3.8453   Max.   : 3.8449   Max.   : 3.6566   Max.   : 3.7812
#     X836.464          X838.315          X840.167          X842.019
#  Min.   :-1.8866   Min.   :-1.8697   Min.   :-1.9059   Min.   :-1.8324
#  1st Qu.:-0.3715   1st Qu.:-0.3709   1st Qu.:-0.3625   1st Qu.:-0.3850
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2426   Mean   : 0.2401   Mean   : 0.2412   Mean   : 0.2301
#  3rd Qu.: 0.6285   3rd Qu.: 0.6291   3rd Qu.: 0.6375   3rd Qu.: 0.6150
#  Max.   : 3.6405   Max.   : 3.6305   Max.   : 3.7757   Max.   : 3.6128
#     X843.871          X845.722          X847.574          X849.426
#  Min.   :-1.8102   Min.   :-1.9806   Min.   :-1.8916   Min.   :-1.8747
#  1st Qu.:-0.3811   1st Qu.:-0.3704   1st Qu.:-0.3710   1st Qu.:-0.3790
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2317   Mean   : 0.2322   Mean   : 0.2439   Mean   : 0.2292
#  3rd Qu.: 0.6189   3rd Qu.: 0.6296   3rd Qu.: 0.6290   3rd Qu.: 0.6210
#  Max.   : 3.9307   Max.   : 4.1911   Max.   : 4.0518   Max.   : 4.0245
#     X851.278          X853.13           X854.981          X856.833
#  Min.   :-2.0829   Min.   :-1.7050   Min.   :-1.7144   Min.   :-1.9409
#  1st Qu.:-0.3918   1st Qu.:-0.3920   1st Qu.:-0.3599   1st Qu.:-0.3760
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2175   Mean   : 0.2133   Mean   : 0.2229   Mean   : 0.2194
#  3rd Qu.: 0.6082   3rd Qu.: 0.6080   3rd Qu.: 0.6401   3rd Qu.: 0.6240
#  Max.   : 3.9424   Max.   : 3.7365   Max.   : 3.5233   Max.   : 3.7114
#     X858.685          X860.537          X862.388          X864.24
#  Min.   :-2.0343   Min.   :-1.8304   Min.   :-1.9570   Min.   :-1.8794
#  1st Qu.:-0.3844   1st Qu.:-0.3871   1st Qu.:-0.3687   1st Qu.:-0.3776
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2214   Mean   : 0.2115   Mean   : 0.2261   Mean   : 0.2200
#  3rd Qu.: 0.6156   3rd Qu.: 0.6129   3rd Qu.: 0.6313   3rd Qu.: 0.6224
#  Max.   : 3.8397   Max.   : 4.0998   Max.   : 3.8775   Max.   : 3.9522
#     X866.092          X867.944          X869.796          X871.647
#  Min.   :-2.1939   Min.   :-1.8672   Min.   :-1.6722   Min.   :-2.104
#  1st Qu.:-0.3958   1st Qu.:-0.3788   1st Qu.:-0.3589   1st Qu.:-0.397
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.000
#  Mean   : 0.2216   Mean   : 0.2285   Mean   : 0.2351   Mean   : 0.215
#  3rd Qu.: 0.6042   3rd Qu.: 0.6212   3rd Qu.: 0.6411   3rd Qu.: 0.603
#  Max.   : 4.0453   Max.   : 4.1000   Max.   : 4.1948   Max.   : 4.103
#     X873.499          X875.351          X877.203          X879.054
#  Min.   :-1.8561   Min.   :-2.0998   Min.   :-2.0047   Min.   :-2.3029
#  1st Qu.:-0.3990   1st Qu.:-0.4068   1st Qu.:-0.4060   1st Qu.:-0.4166
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2169   Mean   : 0.2138   Mean   : 0.2116   Mean   : 0.2104
#  3rd Qu.: 0.6010   3rd Qu.: 0.5932   3rd Qu.: 0.5940   3rd Qu.: 0.5834
#  Max.   : 3.9047   Max.   : 4.3729   Max.   : 4.2836   Max.   : 4.2740
#     X880.906          X882.758          X884.61           X886.462
#  Min.   :-2.2897   Min.   :-1.9613   Min.   :-2.0715   Min.   :-2.3504
#  1st Qu.:-0.4050   1st Qu.:-0.4038   1st Qu.:-0.4129   1st Qu.:-0.4075
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.2077   Mean   : 0.1939   Mean   : 0.1873   Mean   : 0.1902
#  3rd Qu.: 0.5950   3rd Qu.: 0.5962   3rd Qu.: 0.5871   3rd Qu.: 0.5925
#  Max.   : 3.8637   Max.   : 3.8225   Max.   : 3.7663   Max.   : 4.1770
#     X888.313          X890.165          X892.017          X893.869
#  Min.   :-1.9493   Min.   :-2.1232   Min.   :-2.2707   Min.   :-2.3761
#  1st Qu.:-0.4206   1st Qu.:-0.4292   1st Qu.:-0.4063   1st Qu.:-0.4201
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.1765   Mean   : 0.1764   Mean   : 0.1901   Mean   : 0.1731
#  3rd Qu.: 0.5794   3rd Qu.: 0.5708   3rd Qu.: 0.5937   3rd Qu.: 0.5799
#  Max.   : 4.0459   Max.   : 4.3246   Max.   : 4.0431   Max.   : 4.1560
#     X895.72           X897.572          X899.424          X901.276
#  Min.   :-2.3488   Min.   :-2.3140   Min.   :-2.3638   Min.   :-2.17481
#  1st Qu.:-0.4309   1st Qu.:-0.4275   1st Qu.:-0.4237   1st Qu.:-0.43967
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.00000
#  Mean   : 0.1704   Mean   : 0.1355   Mean   : 0.1352   Mean   : 0.09975
#  3rd Qu.: 0.5691   3rd Qu.: 0.5725   3rd Qu.: 0.5763   3rd Qu.: 0.56033
#  Max.   : 4.0695   Max.   : 4.0098   Max.   : 3.8277   Max.   : 3.79610
#     X903.127          X904.979          X906.831          X908.683
#  Min.   :-2.2385   Min.   :-2.3131   Min.   :-2.2827   Min.   :-2.25312
#  1st Qu.:-0.4374   1st Qu.:-0.4432   1st Qu.:-0.4479   1st Qu.:-0.46148
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.00000
#  Mean   : 0.1071   Mean   : 0.1103   Mean   : 0.1051   Mean   : 0.08721
#  3rd Qu.: 0.5626   3rd Qu.: 0.5568   3rd Qu.: 0.5521   3rd Qu.: 0.53851
#  Max.   : 3.6854   Max.   : 4.0446   Max.   : 3.6756   Max.   : 3.74172
#     X910.535           X912.386           X914.238           X916.09
#  Min.   :-2.10778   Min.   :-2.07190   Min.   :-2.04004   Min.   :-1.79973
#  1st Qu.:-0.47608   1st Qu.:-0.47599   1st Qu.:-0.49405   1st Qu.:-0.52048
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   : 0.05588   Mean   : 0.04657   Mean   : 0.02077   Mean   : 0.03522
#  3rd Qu.: 0.52392   3rd Qu.: 0.52401   3rd Qu.: 0.50595   3rd Qu.: 0.47952
#  Max.   : 3.16739   Max.   : 3.13141   Max.   : 3.28247   Max.   : 3.32746
#     X917.942           X919.793           X921.645           X923.497
#  Min.   :-1.92601   Min.   :-1.91201   Min.   :-2.09622   Min.   :-2.06834
#  1st Qu.:-0.52115   1st Qu.:-0.50709   1st Qu.:-0.48627   1st Qu.:-0.48765
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   : 0.02265   Mean   : 0.03166   Mean   : 0.03493   Mean   : 0.03594
#  3rd Qu.: 0.47885   3rd Qu.: 0.49291   3rd Qu.: 0.51373   3rd Qu.: 0.51235
#  Max.   : 3.23919   Max.   : 3.22227   Max.   : 3.97098   Max.   : 3.34997
#     X925.349           X927.201           X929.052            X930.904
#  Min.   :-2.00383   Min.   :-1.80433   Min.   :-1.568738   Min.   :-1.3882
#  1st Qu.:-0.51154   1st Qu.:-0.50615   1st Qu.:-0.513698   1st Qu.:-0.4022
#  Median : 0.00000   Median : 0.00000   Median : 0.000000   Median : 0.0000
#  Mean   : 0.03493   Mean   : 0.04666   Mean   : 0.008403   Mean   : 0.1160
#  3rd Qu.: 0.48846   3rd Qu.: 0.49385   3rd Qu.: 0.486302   3rd Qu.: 0.5978
#  Max.   : 3.16820   Max.   : 3.01625   Max.   : 2.639130   Max.   : 2.6527
#     X932.756           X934.608           X936.459          X938.311
#  Min.   :-1.37310   Min.   :-1.16833   Min.   :-1.0396   Min.   :-0.98731
#  1st Qu.:-0.48486   1st Qu.:-0.44728   1st Qu.:-0.4518   1st Qu.:-0.46203
#  Median : 0.00000   Median : 0.00000   Median : 0.0000   Median : 0.00000
#  Mean   : 0.07523   Mean   : 0.09718   Mean   : 0.0884   Mean   : 0.08011
#  3rd Qu.: 0.51514   3rd Qu.: 0.55272   3rd Qu.: 0.5482   3rd Qu.: 0.53797
#  Max.   : 3.44966   Max.   : 3.45244   Max.   : 3.8708   Max.   : 3.44498
#     X940.163           X942.015           X943.867           X945.718
#  Min.   :-1.03061   Min.   :-1.04151   Min.   :-1.07676   Min.   :-1.0293
#  1st Qu.:-0.47912   1st Qu.:-0.45664   1st Qu.:-0.47570   1st Qu.:-0.4467
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.0000
#  Mean   : 0.08509   Mean   : 0.09371   Mean   : 0.07782   Mean   : 0.1012
#  3rd Qu.: 0.52088   3rd Qu.: 0.54336   3rd Qu.: 0.52430   3rd Qu.: 0.5533
#  Max.   : 3.66679   Max.   : 3.42965   Max.   : 3.57637   Max.   : 3.7480
#     X947.57           X949.422           X951.274           X953.125
#  Min.   :-1.0032   Min.   :-1.01185   Min.   :-0.98590   Min.   :-0.9825
#  1st Qu.:-0.4502   1st Qu.:-0.45175   1st Qu.:-0.44445   1st Qu.:-0.4481
#  Median : 0.0000   Median : 0.00000   Median : 0.00000   Median : 0.0000
#  Mean   : 0.1014   Mean   : 0.08684   Mean   : 0.09681   Mean   : 0.1055
#  3rd Qu.: 0.5498   3rd Qu.: 0.54825   3rd Qu.: 0.55555   3rd Qu.: 0.5519
#  Max.   : 3.7994   Max.   : 3.89430   Max.   : 3.91701   Max.   : 3.6346
#     X954.977           X956.829          X958.681          X960.533
#  Min.   :-1.08067   Min.   :-1.0762   Min.   :-1.0343   Min.   :-1.0201
#  1st Qu.:-0.44732   1st Qu.:-0.4293   1st Qu.:-0.4558   1st Qu.:-0.4482
#  Median : 0.00000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.09193   Mean   : 0.1075   Mean   : 0.1027   Mean   : 0.0960
#  3rd Qu.: 0.55268   3rd Qu.: 0.5707   3rd Qu.: 0.5442   3rd Qu.: 0.5518
#  Max.   : 3.78047   Max.   : 3.3225   Max.   : 4.1453   Max.   : 3.3419
#     X962.384           X964.236           X966.088          X967.94
#  Min.   :-1.10408   Min.   :-1.10135   Min.   :-1.0549   Min.   :-1.1486
#  1st Qu.:-0.47437   1st Qu.:-0.46339   1st Qu.:-0.4571   1st Qu.:-0.4424
#  Median : 0.00000   Median : 0.00000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.08587   Mean   : 0.08891   Mean   : 0.0849   Mean   : 0.1087
#  3rd Qu.: 0.52563   3rd Qu.: 0.53661   3rd Qu.: 0.5429   3rd Qu.: 0.5576
#  Max.   : 3.22478   Max.   : 3.61055   Max.   : 4.0907   Max.   : 3.4488
#     X969.791          X971.643           X973.495           X975.347
#  Min.   :-1.1304   Min.   :-1.22005   Min.   :-1.23424   Min.   :-1.1806
#  1st Qu.:-0.4434   1st Qu.:-0.49064   1st Qu.:-0.48167   1st Qu.:-0.4512
#  Median : 0.0000   Median : 0.00000   Median : 0.00000   Median : 0.0000
#  Mean   : 0.1070   Mean   : 0.07876   Mean   : 0.08523   Mean   : 0.1119
#  3rd Qu.: 0.5566   3rd Qu.: 0.50936   3rd Qu.: 0.51833   3rd Qu.: 0.5488
#  Max.   : 3.4294   Max.   : 3.59160   Max.   : 3.55634   Max.   : 3.6023
#     X977.199           X979.05            X980.902           X982.754
#  Min.   :-1.12843   Min.   :-1.13133   Min.   :-1.13446   Min.   :-1.1182
#  1st Qu.:-0.44409   1st Qu.:-0.43948   1st Qu.:-0.44247   1st Qu.:-0.4332
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.0000
#  Mean   : 0.09803   Mean   : 0.09286   Mean   : 0.09358   Mean   : 0.1053
#  3rd Qu.: 0.55591   3rd Qu.: 0.56052   3rd Qu.: 0.55753   3rd Qu.: 0.5668
#  Max.   : 3.56185   Max.   : 3.09057   Max.   : 3.83733   Max.   : 4.0047
#     X984.606          X986.457           X988.309          X990.161
#  Min.   :-1.1535   Min.   :-1.14537   Min.   :-1.1127   Min.   :-1.12131
#  1st Qu.:-0.4276   1st Qu.:-0.44190   1st Qu.:-0.4328   1st Qu.:-0.42675
#  Median : 0.0000   Median : 0.00000   Median : 0.0000   Median : 0.00000
#  Mean   : 0.1021   Mean   : 0.09001   Mean   : 0.1067   Mean   : 0.08868
#  3rd Qu.: 0.5724   3rd Qu.: 0.55810   3rd Qu.: 0.5672   3rd Qu.: 0.57325
#  Max.   : 3.2936   Max.   : 3.62764   Max.   : 3.4605   Max.   : 3.98972
#     X992.013           X993.865           X995.716         X397.593_5nm
#  Min.   :-1.10010   Min.   :-1.08388   Min.   :-1.11777   Min.   :-1.43349
#  1st Qu.:-0.42618   1st Qu.:-0.45961   1st Qu.:-0.47238   1st Qu.:-0.58439
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   : 0.09766   Mean   : 0.09209   Mean   : 0.06963   Mean   :-0.05216
#  3rd Qu.: 0.57382   3rd Qu.: 0.54039   3rd Qu.: 0.52762   3rd Qu.: 0.41561
#  Max.   : 3.52986   Max.   : 3.50683   Max.   : 3.24423   Max.   : 2.82690
#   X402.593_5nm       X407.593_5nm       X412.593_5nm       X417.593_5nm
#  Min.   :-1.21169   Min.   :-1.28856   Min.   :-1.17964   Min.   :-1.15294
#  1st Qu.:-0.59546   1st Qu.:-0.59559   1st Qu.:-0.58230   1st Qu.:-0.56811
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.06945   Mean   :-0.07053   Mean   :-0.06022   Mean   :-0.04858
#  3rd Qu.: 0.40454   3rd Qu.: 0.40441   3rd Qu.: 0.41769   3rd Qu.: 0.43189
#  Max.   : 1.47839   Max.   : 1.46966   Max.   : 1.73533   Max.   : 1.81321
#   X422.593_5nm      X427.593_5nm      X432.593_5nm       X437.593_5nm
#  Min.   :-1.1907   Min.   :-1.1371   Min.   :-1.15155   Min.   :-1.1398
#  1st Qu.:-0.5626   1st Qu.:-0.5562   1st Qu.:-0.55326   1st Qu.:-0.5480
#  Median : 0.0000   Median : 0.0000   Median : 0.00000   Median : 0.0000
#  Mean   :-0.0465   Mean   :-0.0421   Mean   :-0.04067   Mean   :-0.0386
#  3rd Qu.: 0.4374   3rd Qu.: 0.4438   3rd Qu.: 0.44674   3rd Qu.: 0.4520
#  Max.   : 1.8404   Max.   : 1.9320   Max.   : 1.99111   Max.   : 2.0315
#   X442.593_5nm       X447.593_5nm       X452.593_5nm       X457.593_5nm
#  Min.   :-1.13480   Min.   :-1.11105   Min.   :-1.08100   Min.   :-1.10074
#  1st Qu.:-0.54098   1st Qu.:-0.53495   1st Qu.:-0.53111   1st Qu.:-0.52923
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.03206   Mean   :-0.02826   Mean   :-0.02559   Mean   :-0.02445
#  3rd Qu.: 0.45902   3rd Qu.: 0.46505   3rd Qu.: 0.46889   3rd Qu.: 0.47077
#  Max.   : 2.04600   Max.   : 2.05217   Max.   : 2.05640   Max.   : 2.05833
#   X462.593_5nm       X467.593_5nm       X472.593_5nm       X477.593_5nm
#  Min.   :-1.09558   Min.   :-1.06989   Min.   :-1.06858   Min.   :-1.06634
#  1st Qu.:-0.53316   1st Qu.:-0.53611   1st Qu.:-0.53493   1st Qu.:-0.53448
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.02667   Mean   :-0.02742   Mean   :-0.02502   Mean   :-0.02455
#  3rd Qu.: 0.46684   3rd Qu.: 0.46389   3rd Qu.: 0.46507   3rd Qu.: 0.46552
#  Max.   : 2.04341   Max.   : 2.02993   Max.   : 2.02723   Max.   : 2.02267
#   X482.593_5nm       X487.593_5nm       X492.593_5nm       X497.593_5nm
#  Min.   :-1.07413   Min.   :-1.07944   Min.   :-1.09457   Min.   :-1.14606
#  1st Qu.:-0.53706   1st Qu.:-0.53376   1st Qu.:-0.53204   1st Qu.:-0.52986
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   :-0.02586   Mean   :-0.02471   Mean   :-0.02411   Mean   :-0.02424
#  3rd Qu.: 0.46294   3rd Qu.: 0.46624   3rd Qu.: 0.46796   3rd Qu.: 0.47014
#  Max.   : 2.02341   Max.   : 2.01224   Max.   : 2.01847   Max.   : 2.03161
#   X502.593_5nm       X507.593_5nm       X512.593_5nm       X517.593_5nm
#  Min.   :-1.15296   Min.   :-1.18707   Min.   :-1.26247   Min.   :-1.312310
#  1st Qu.:-0.52353   1st Qu.:-0.51475   1st Qu.:-0.50240   1st Qu.:-0.485799
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.000000
#  Mean   :-0.02264   Mean   :-0.01919   Mean   :-0.01498   Mean   :-0.007072
#  3rd Qu.: 0.47647   3rd Qu.: 0.48525   3rd Qu.: 0.49760   3rd Qu.: 0.514200
# ...
#  Max.   : 8.31004   Max.   : 3.0078   Max.   :15.0450   Max.   :12.0461
#       CRI3              CRI4               D1                  D2
#  Min.   :-1.3935   Min.   :-1.4547   Min.   :-212.7349   Min.   :-5386.150
#  1st Qu.:-0.4881   1st Qu.:-0.4827   1st Qu.:  -0.4952   1st Qu.:   -0.484
#  Median : 0.0000   Median : 0.0000   Median :   0.0000   Median :    0.000
#  Mean   : 0.1464   Mean   : 0.1479   Mean   :   0.9944   Mean   :   -0.832
#  3rd Qu.: 0.5119   3rd Qu.: 0.5173   3rd Qu.:   0.5048   3rd Qu.:    0.516
#  Max.   : 8.6220   Max.   : 8.6634   Max.   :1600.7494   Max.   :  695.073
#       Datt               Datt2              Datt3               Datt4
#  Min.   :-59.32199   Min.   :-3.70557   Min.   :-257.2936   Min.   :-1.7989
#  1st Qu.: -0.51788   1st Qu.:-0.45334   1st Qu.:  -0.4954   1st Qu.:-0.4719
#  Median :  0.00000   Median : 0.00000   Median :   0.0000   Median : 0.0000
#  Mean   : -0.08282   Mean   : 0.09845   Mean   :   0.1840   Mean   : 0.1273
#  3rd Qu.:  0.48212   3rd Qu.: 0.54666   3rd Qu.:   0.5046   3rd Qu.: 0.5281
#  Max.   :  2.96799   Max.   : 8.05320   Max.   :1205.5766   Max.   :16.0409
#      Datt5              Datt6               DD               DDn
#  Min.   :-3.02544   Min.   :-1.3738   Min.   :-2.5709   Min.   :-4.6493
#  1st Qu.:-0.47127   1st Qu.:-0.4089   1st Qu.:-0.4855   1st Qu.:-0.5976
#  Median : 0.00000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.06261   Mean   : 0.2583   Mean   : 0.0570   Mean   :-0.1951
#  3rd Qu.: 0.52873   3rd Qu.: 0.5910   3rd Qu.: 0.5145   3rd Qu.: 0.4024
#  Max.   : 5.73777   Max.   :33.1003   Max.   : 4.8905   Max.   : 1.7074
#       DPI                 DWSI4              EGFN               EGFR
#  Min.   :-9.095e+04   Min.   :-1.9252   Min.   :-2.86091   Min.   :-1.5554
#  1st Qu.: 0.000e+00   1st Qu.:-0.4407   1st Qu.:-0.51235   1st Qu.:-0.4412
#  Median : 0.000e+00   Median : 0.0000   Median : 0.00000   Median : 0.0000
#  Mean   : 2.250e+06   Mean   : 0.1404   Mean   :-0.04261   Mean   : 0.1184
#  3rd Qu.: 1.000e+00   3rd Qu.: 0.5593   3rd Qu.: 0.48765   3rd Qu.: 0.5588
#  Max.   : 1.091e+10   Max.   :10.0429   Max.   : 2.07217   Max.   : 4.9908
#       EVI              GDVI2             GDVI3              GDVI4
#  Min.   :-1.4792   Min.   :-7.0277   Min.   :-14.4866   Min.   :-30.3920
#  1st Qu.:-0.3923   1st Qu.:-0.5879   1st Qu.: -0.6348   1st Qu.: -0.6769
#  Median : 0.0000   Median : 0.0000   Median :  0.0000   Median :  0.0000
#  Mean   : 0.2116   Mean   :-0.1778   Mean   : -0.3167   Mean   : -0.4836
#  3rd Qu.: 0.6077   3rd Qu.: 0.4121   3rd Qu.:  0.3652   3rd Qu.:  0.3231
#  Max.   : 4.2393   Max.   : 1.3519   Max.   :  0.8740   Max.   :  0.6296
#        GI             Gitelson         Gitelson2             GMI1
#  Min.   :-2.0415   Min.   :-1.3268   Min.   :-13.6550   Min.   :-1.97839
#  1st Qu.:-0.4158   1st Qu.:-0.4922   1st Qu.: -0.5420   1st Qu.:-0.46527
#  Median : 0.0000   Median : 0.0000   Median :  0.0000   Median : 0.00000
#  Mean   : 0.1699   Mean   : 0.1495   Mean   : -0.1307   Mean   : 0.07236
#  3rd Qu.: 0.5842   3rd Qu.: 0.5078   3rd Qu.:  0.4580   3rd Qu.: 0.53473
#  Max.   : 9.3699   Max.   : 9.2510   Max.   :  2.1302   Max.   : 7.38591
#       GMI2            GreenNDVI           Maccioni            MCARI
#  Min.   :-1.91414   Min.   :-3.68794   Min.   :-4.45656   Min.   :-1.5520
#  1st Qu.:-0.48296   1st Qu.:-0.55509   1st Qu.:-0.50839   1st Qu.:-0.4153
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.0000
#  Mean   : 0.07375   Mean   :-0.06987   Mean   :-0.01747   Mean   : 0.1948
#  3rd Qu.: 0.51704   3rd Qu.: 0.44491   3rd Qu.: 0.49161   3rd Qu.: 0.5847
#  Max.   : 4.93811   Max.   : 2.39964   Max.   : 3.99987   Max.   : 5.8065
#    MCARIOSAVI          MCARI2         MCARI2OSAVI2         mND705
#  Min.   :-2.1782   Min.   :-1.4392   Min.   :-2.0061   Min.   :-2.79321
#  1st Qu.:-0.4431   1st Qu.:-0.3938   1st Qu.:-0.4277   1st Qu.:-0.49588
#  Median : 0.0000   Median : 0.0000   Median : 0.0000   Median : 0.00000
#  Mean   : 0.1115   Mean   : 0.2216   Mean   : 0.1665   Mean   : 0.02863
#  3rd Qu.: 0.5569   3rd Qu.: 0.6062   3rd Qu.: 0.5723   3rd Qu.: 0.50412
#  Max.   : 5.1076   Max.   : 6.3513   Max.   : 5.1788   Max.   : 4.54699
#      mNDVI               MPRI              MSAVI              mSR
#  Min.   :-3.38093   Min.   :-4.42427   Min.   :-1.7524   Min.   :-435.6507
#  1st Qu.:-0.47698   1st Qu.:-0.55202   1st Qu.:-0.4113   1st Qu.:  -0.3346
#  Median : 0.00000   Median : 0.00000   Median : 0.0000   Median :   0.0000
#  Mean   : 0.03159   Mean   :-0.06196   Mean   : 0.1587   Mean   :   0.1160
#  3rd Qu.: 0.52302   3rd Qu.: 0.44798   3rd Qu.: 0.5887   3rd Qu.:   0.6654
#  Max.   : 5.35412   Max.   : 3.33614   Max.   : 3.4929   Max.   :1661.5095
#       mSR2              mSR705             MTCI              MTVI
#  Min.   :-2.22352   Min.   :-1.8867   Min.   :-2.0362   Min.   :-1.6011
#  1st Qu.:-0.48064   1st Qu.:-0.4540   1st Qu.:-0.4591   1st Qu.:-0.3955
#  Median : 0.00000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.06964   Mean   : 0.1437   Mean   : 0.1112   Mean   : 0.2175
#  3rd Qu.: 0.51936   3rd Qu.: 0.5460   3rd Qu.: 0.5409   3rd Qu.: 0.6045
#  Max.   : 8.16638   Max.   :18.9329   Max.   : 6.8863   Max.   : 4.5265
#       NDVI              NDVI2               NDVI3               NPCI
#  Min.   :-3.69019   Min.   :-2.960341   Min.   :-2.67273   Min.   :-3.999186
#  1st Qu.:-0.53532   1st Qu.:-0.508946   1st Qu.:-0.52792   1st Qu.:-0.515529
#  Median : 0.00000   Median : 0.000000   Median : 0.00000   Median : 0.000000
#  Mean   :-0.04929   Mean   : 0.001946   Mean   :-0.02564   Mean   :-0.009423
#  3rd Qu.: 0.46468   3rd Qu.: 0.491054   3rd Qu.: 0.47208   3rd Qu.: 0.484471
#  Max.   : 2.60623   Max.   : 4.188197   Max.   : 3.27624   Max.   : 3.670881
#      OSAVI              OSAVI2              PARS               PRI
#  Min.   :-2.74102   Min.   :-2.52208   Min.   :-2.06263   Min.   :-3.18019
#  1st Qu.:-0.48072   1st Qu.:-0.45357   1st Qu.:-0.49702   1st Qu.:-0.46358
#  Median : 0.00000   Median : 0.00000   Median : 0.00000   Median : 0.00000
#  Mean   : 0.04373   Mean   : 0.05367   Mean   : 0.04428   Mean   : 0.05357
#  3rd Qu.: 0.51928   3rd Qu.: 0.54643   3rd Qu.: 0.50298   3rd Qu.: 0.53642
#  Max.   : 2.68214   Max.   : 2.92970   Max.   : 5.24017   Max.   : 5.53682
#     PRInorm             PRICI2               PSND              PSRI
#  Min.   :-5.55440   Min.   :-9.376620   Min.   :-4.8695   Min.   :-3.55315
#  1st Qu.:-0.45441   1st Qu.:-0.486792   1st Qu.:-0.5543   1st Qu.:-0.50865
#  Median : 0.00000   Median : 0.000000   Median : 0.0000   Median : 0.00000
#  Mean   : 0.08062   Mean   :-0.002206   Mean   :-0.1065   Mean   : 0.01127
#  3rd Qu.: 0.54559   3rd Qu.: 0.513208   3rd Qu.: 0.4457   3rd Qu.: 0.49135
#  Max.   : 8.82189   Max.   : 5.792392   Max.   : 2.2022   Max.   : 5.64886
#       PSSR              RDVI              REPLE                REPLi
#  Min.   :-2.1631   Min.   :-2.45036   Min.   :-1884.1860   Min.   :-3.76038
#  1st Qu.:-0.4531   1st Qu.:-0.45498   1st Qu.:   -0.5180   1st Qu.:-0.48016
#  Median : 0.0000   Median : 0.00000   Median :    0.0000   Median : 0.00000
#  Mean   : 0.1150   Mean   : 0.09935   Mean   :   -0.9116   Mean   : 0.07002
#  3rd Qu.: 0.5469   3rd Qu.: 0.54502   3rd Qu.:    0.4820   3rd Qu.: 0.51984
#  Max.   : 5.6205   Max.   : 3.15269   Max.   :  346.5560   Max.   : 8.64655
#       SAVI              SIPI               SPVI              SR
#  Min.   :-2.0600   Min.   :-3.17036   Min.   :-1.622   Min.   :-1.7229
#  1st Qu.:-0.4330   1st Qu.:-0.49079   1st Qu.:-0.398   1st Qu.:-0.4586
#  Median : 0.0000   Median : 0.00000   Median : 0.000   Median : 0.0000
#  Mean   : 0.1103   Mean   : 0.05116   Mean   : 0.183   Mean   : 0.1442
#  3rd Qu.: 0.5670   3rd Qu.: 0.50921   3rd Qu.: 0.602   3rd Qu.: 0.5414
#  Max.   : 2.9569   Max.   : 6.01438   Max.   : 3.997   Max.   :13.2449
#       SR1                SR2               SR3                SR4
#  Min.   :-1.91414   Min.   :-1.5659   Min.   :-1.97839   Min.   :-2.60260
#  1st Qu.:-0.48296   1st Qu.:-0.4469   1st Qu.:-0.46527   1st Qu.:-0.47984
#  Median : 0.00000   Median : 0.0000   Median : 0.00000   Median : 0.00000
#  Mean   : 0.07375   Mean   : 0.1353   Mean   : 0.07236   Mean   : 0.09176
#  3rd Qu.: 0.51704   3rd Qu.: 0.5531   3rd Qu.: 0.53473   3rd Qu.: 0.52016
#  Max.   : 4.93811   Max.   : 9.9510   Max.   : 7.38591   Max.   :18.30258
#       SR5              SR6               SR7                SR8
#  Min.   :-4.151   Min.   :-2.0442   Min.   :-1.94647   Min.   :-3.4264
#  1st Qu.:-0.474   1st Qu.:-0.4681   1st Qu.:-0.47776   1st Qu.:-0.4850
#  Median : 0.000   Median : 0.0000   Median : 0.00000   Median : 0.0000
#  Mean   : 0.057   Mean   : 0.0791   Mean   : 0.09001   Mean   : 0.0591
#  3rd Qu.: 0.526   3rd Qu.: 0.5319   3rd Qu.: 0.52224   3rd Qu.: 0.5150
#  Max.   : 4.426   Max.   : 8.3978   Max.   :15.43644   Max.   : 4.4692
#       SRPI             SumDr1             SumDr2            TCARI
#  Min.   :-2.2067   Min.   :-1.81558   Min.   :-1.6647   Min.   :-2.2623
#  1st Qu.:-0.4408   1st Qu.:-0.49393   1st Qu.:-0.4613   1st Qu.:-0.4153
#  Median : 0.0000   Median : 0.00000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.1270   Mean   : 0.05278   Mean   : 0.1798   Mean   : 0.1978
#  3rd Qu.: 0.5592   3rd Qu.: 0.50608   3rd Qu.: 0.5387   3rd Qu.: 0.5847
#  Max.   :13.1221   Max.   : 3.80889   Max.   : 4.7163   Max.   : 5.4097
#    TCARIOSAVI           TCARI2         TCARI2OSAVI2          TGI
#  Min.   :-3.78607   Min.   :-3.1178   Min.   :-4.9017   Min.   :-2.1338
#  1st Qu.:-0.46811   1st Qu.:-0.4042   1st Qu.:-0.4417   1st Qu.:-0.4577
#  Median : 0.00000   Median : 0.0000   Median : 0.0000   Median : 0.0000
#  Mean   : 0.09379   Mean   : 0.2038   Mean   : 0.1106   Mean   : 0.1932
#  3rd Qu.: 0.53189   3rd Qu.: 0.5958   3rd Qu.: 0.5583   3rd Qu.: 0.5423
#  Max.   : 3.95498   Max.   : 4.9078   Max.   : 3.8028   Max.   : 5.5783
#       TVI            Vogelmann          Vogelmann2         Vogelmann3
#  Min.   :-1.4842   Min.   :-3.57440   Min.   :-6.27390   Min.   :-439.7848
#  1st Qu.:-0.3849   1st Qu.:-0.44601   1st Qu.:-0.50802   1st Qu.:  -0.4182
#  Median : 0.0000   Median : 0.00000   Median : 0.00000   Median :   0.0000
#  Mean   : 0.2233   Mean   : 0.09825   Mean   :-0.03392   Mean   :   0.0323
#  3rd Qu.: 0.6151   3rd Qu.: 0.55399   3rd Qu.: 0.49198   3rd Qu.:   0.5818
#  Max.   : 4.5959   Max.   : 6.25692   Max.   : 5.50828   Max.   : 628.1444
#    Vogelmann4
#  Min.   :-7.16988
#  1st Qu.:-0.51261
#  Median : 0.00000
#  Mean   :-0.04284
#  3rd Qu.: 0.48739
#  Max.   : 5.77577
#           x        y z
# 1 -148.2962 64.70435 3
# 2 -148.2962 64.70435 3
# 3 -148.2962 64.70435 7
# 4 -148.2962 64.70435 3
# 5 -148.2962 64.70435 3
# 6 -148.2962 64.70435 3
#           x        y z
# 1 -148.2962 64.70435 3
# 2 -148.2962 64.70435 3
# 3 -148.2962 64.70435 7
# 4 -148.2962 64.70435 3
# 5 -148.2962 64.70435 3
# 6 -148.2962 64.70435 3
# [1] "Attempting to save to ./validation_saved_output.grd"
# [1] "Converted to Raster"
# Reading layer `Bonanza_N_Quads' from data source
#   `/home/krbundy/GitHub/lecospec/Data/Vectors/Bonanza_N_Quads.shp'
#   using driver `ESRI Shapefile'
# Simple feature collection with 11 features and 3 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: 438153.7 ymin: 7176051 xmax: 438205.6 ymax: 7176138
# Projected CRS: WGS 84 / UTM zone 6N
#  [1] "Bonanza60"  "Bonanza100" "Bonanza90"  "Bonanza80"  "Bonanza50"
#  [6] "Bonanza40"  "Bonanza30"  "Bonanza20"  "Bonanza10"  "Bonanza0"
# [11] "Bonanza70"
# Simple feature collection with 1 feature and 3 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: -148.2966 ymin: 64.70403 xmax: -148.2966 ymax: 64.70404
# Geodetic CRS:  GCS_unknown
#   CLASS_NAME CLASS_ID CLASS_CLRS                       geometry
# 1  Bonanza60        7    128,0,0 POLYGON ((-148.2966 64.7040...
# Saving 6.67 x 6.67 in image
# Simple feature collection with 1 feature and 3 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: -148.2962 ymin: 64.70434 xmax: -148.2962 ymax: 64.70435
# Geodetic CRS:  GCS_unknown
#   CLASS_NAME CLASS_ID CLASS_CLRS                       geometry
# 2 Bonanza100       11  127,255,0 POLYGON ((-148.2962 64.7043...
# Saving 6.67 x 6.67 in image
# Simple feature collection with 1 feature and 3 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: -148.2963 ymin: 64.70426 xmax: -148.2963 ymax: 64.70428
# Geodetic CRS:  GCS_unknown
#   CLASS_NAME CLASS_ID CLASS_CLRS                       geometry
# 3  Bonanza90       10 255,127,80 POLYGON ((-148.2963 64.7042...
# Saving 6.67 x 6.67 in image
# Simple feature collection with 1 feature and 3 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: -148.2964 ymin: 64.70418 xmax: -148.2964 ymax: 64.7042
# Geodetic CRS:  GCS_unknown
#   CLASS_NAME CLASS_ID CLASS_CLRS                       geometry
# 4  Bonanza80        9    0,0,128 POLYGON ((-148.2964 64.7042...
# Saving 6.67 x 6.67 in image
# Simple feature collection with 1 feature and 3 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: -148.2967 ymin: 64.70395 xmax: -148.2967 ymax: 64.70396
# Geodetic CRS:  GCS_unknown
#   CLASS_NAME CLASS_ID CLASS_CLRS                       geometry
# 5  Bonanza50        6  255,0,255 POLYGON ((-148.2967 64.7039...
# Saving 6.67 x 6.67 in image
# Simple feature collection with 1 feature and 3 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: -148.2968 ymin: 64.70387 xmax: -148.2968 ymax: 64.70388
# Geodetic CRS:  GCS_unknown
#   CLASS_NAME CLASS_ID CLASS_CLRS                       geometry
# 6  Bonanza40        5  0,255,255 POLYGON ((-148.2968 64.7038...
# Saving 6.67 x 6.67 in image
# Simple feature collection with 1 feature and 3 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: -148.2969 ymin: 64.70379 xmax: -148.2969 ymax: 64.7038
# Geodetic CRS:  GCS_unknown
#   CLASS_NAME CLASS_ID CLASS_CLRS                       geometry
# 7  Bonanza30        4  255,255,0 POLYGON ((-148.2969 64.7038...
# Saving 6.67 x 6.67 in image
# Simple feature collection with 1 feature and 3 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: -148.297 ymin: 64.70371 xmax: -148.297 ymax: 64.70373
# Geodetic CRS:  GCS_unknown
#   CLASS_NAME CLASS_ID CLASS_CLRS                       geometry
# 8  Bonanza20        3    0,0,255 POLYGON ((-148.297 64.70373...
# Saving 6.67 x 6.67 in image
# Simple feature collection with 1 feature and 3 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: -148.2971 ymin: 64.70364 xmax: -148.2971 ymax: 64.70365
# Geodetic CRS:  GCS_unknown
#   CLASS_NAME CLASS_ID CLASS_CLRS                       geometry
# 9  Bonanza10        2    0,128,0 POLYGON ((-148.2971 64.7036...
# Saving 6.67 x 6.67 in image
# Simple feature collection with 1 feature and 3 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: -148.2972 ymin: 64.70356 xmax: -148.2972 ymax: 64.70357
# Geodetic CRS:  GCS_unknown
#    CLASS_NAME CLASS_ID CLASS_CLRS                       geometry
# 10   Bonanza0        1    255,0,0 POLYGON ((-148.2972 64.7035...
# Saving 6.67 x 6.67 in image
# Simple feature collection with 1 feature and 3 fields
# Geometry type: POLYGON
# Dimension:     XY
# Bounding box:  xmin: -148.2965 ymin: 64.70411 xmax: -148.2965 ymax: 64.70412
# Geodetic CRS:  GCS_unknown
#    CLASS_NAME CLASS_ID CLASS_CLRS                       geometry
# 11  Bonanza70        8    0,255,0 POLYGON ((-148.2965 64.7041...
# Saving 6.67 x 6.67 in image
# [1] "z"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image

# %%
   print(model$forest$independent.variable.names)

# %%
library(kernlab)
sink(NULL)
print(colnames(standardized_indices[,1:95]))

# %%
# time to build the SVMs directly
  # train and print intermediate results to console
        include_top <- 35
        df <- data.frame(standardized_indices[,1:95][,important_variable_names[1:include_top]])
        #print(colnames(df))
        #df$targets <-  as.factor(targets) 
        print("Beginning Training")
        model <- train(
            x=standardized_validation[permutation,][samples,][,important_variable_names[1:include_top]] %>% as.matrix,
            y=test_labels,
            method="knn",
            trControl = fit_ctrl
            #type = "C-bsvc",#"spoc-svc",
            #kernel = "rbfdot",
            #kpar = "automatic",
            #C = 60,
            #cross = 3
        )
        
        #print(model)

        model_predictions <- predict(
            model, 
            newdata=standardized_validation[permutation,][samples,][,important_variable_names[1:include_top]] %>% as.matrix
        )#$response %>% as.factor()
        #print(model_predictions)
        
        test_samples <- test_labels %>% as.factor()
        levels(test_samples) <- c(levels(test_samples), "Forb")

        confusion_matrix <- caret::confusionMatrix(
            model_predictions, 
            test_samples,
            mode = "everything"
        )

        model_id <- uuid::UUIDgenerate()

        # append performance data to the logs for later comparison
        sink(file = "mle/log_svm.txt", append = TRUE, type = "output")
        print("-------------------------------------------------------")
        print("---------------------- Model Data ---------------------")
        
        print(paste0("Model Type: SVM"))
        print(paste0("Data Index: ",i))
        print(paste0("Model UUID: ", model_id))
        print(paste0("Selected Variables: ", colnames(df)))
        print("---------------------- Confusion Matrix ---------------------")
        print(confusion_matrix)
        print("---------------------- Class Distribution ---------------------")
        print(model_predictions %>% as.factor() %>% table())
        print("-------------------------------------------------------")
        sink(NULL)

        
        save(model, file = paste0("mle/models/gs/", model_id, ".rda"))

# %%
markdown_text <- "# Grid Search Results\n"
base_path <- "mle/experiments/gs/"

dirs <- list.dirs(base_path, full.names = FALSE, recursive = FALSE)
for(dir in dirs){
    files <- list.files(paste0(base_path, dir), pattern = ".html", full.names = TRUE)
    md_str <- paste0(
        dir,
        "\t [Graph](",
        files[1],
        ")\t|\t[Table](",
        files[2],
        ")\n"
    )
    markdown_text <- paste0(markdown_text, md_str)
    
}

write(markdown_text, file = "gs.md")

# %%
make_tukey_mean_difference_plot(v1, v2, )

# %%
source("Scripts/validation_defs.R")

bg_shape <- sf::st_read(shape_path_1)$CLASS_NAME

# %%
bg_raster <- terra::rast("validation_saved_output.grd")

# %%
rasterVis::levelplot(bg_raster)
#plot(bg_shape)

# %%
write.csv(test_data, file="assets/test_data.csv")
write.csv(test_labels %>% as.data.frame(), file="assets/test_cl.csv")

# %%
knn_LSModel <- LSModel(
    model = list(),
    predict_function <- function(df, model, ...){
        base_data <- read.csv("assets/test_data.csv")
        base_labels <- read.csv("assets/test_cl.csv")
        predictions <- class::knn(base_data, df, base_labels, k=5) %>% as.data.frame()
        colnames(predictions) <- c("z")
        return(predictions)
    }
)

# %% [markdown]
# # Results
#
# These are the results of the grid search on the basics.  High performing models get to go through validation
#
# ## Top performers:
# * Architectures: Random Forest, SVM, kNN, and RF-LDA.  A 5th would be nice, maybe PLS.
# * variable selection can improve performance
# *
