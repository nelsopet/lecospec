# %%
import pandas as pd
import numpy as np
from scipy.interpolate import CubicSpline

from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, train_test_split, StratifiedShuffleSplit
from sklearn.metrics import f1_score, balanced_accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC

# %%
speclib = pd.read_csv("/home/krbundy/GitHub/lecospec/Output/C_001_SC3_Cleaned_SpectralLib.csv", low_memory=False)
speclib.head()
# Out:
#    Unnamed: 0            ScanID    Area Code_name          Species_name  \
# 0           1  aleoch_Murph_061  Murphy    aleoch  Alectoria ochroleuca
# 1           2  aleoch_Murph_063  Murphy    aleoch  Alectoria ochroleuca
# 2           3  aleoch_Murph_064  Murphy    aleoch  Alectoria ochroleuca
# 3           4  aleoch_Murph_065  Murphy    aleoch  Alectoria ochroleuca
# 4           5  aleoch_Murph_066  Murphy    aleoch  Alectoria ochroleuca
#
#   Functional_group1            Functional_group2  Species_name_Freq  \
# 0            Lichen  LightTerrestrialMacrolichen                6.0
# 1            Lichen  LightTerrestrialMacrolichen                6.0
# 2            Lichen  LightTerrestrialMacrolichen                6.0
# 3            Lichen  LightTerrestrialMacrolichen                6.0
# 4            Lichen  LightTerrestrialMacrolichen                6.0
#
#    Functional_group1_Freq  Functional_group2_Freq  ...  \
# 0                   453.0                   118.0  ...
# 1                   453.0                   118.0  ...
# 2                   453.0                   118.0  ...
# 3                   453.0                   118.0  ...
# 4                   453.0                   118.0  ...
#
#   Radiometric.Calibration  Units  Latitude  Longitude  Altitude  GPS.Time  \
# 0                     NaN    NaN       NaN        NaN       NaN       NaN
# 1                     NaN    NaN       NaN        NaN       NaN       NaN
# 2                     NaN    NaN       NaN        NaN       NaN       NaN
# 3                     NaN    NaN       NaN        NaN       NaN       NaN
# 4                     NaN    NaN       NaN        NaN       NaN       NaN
#
#    Satellites  Calibrated.Reference.Correction.File  Channels  ScanNum
# 0         NaN                                   NaN       NaN      NaN
# 1         NaN                                   NaN       NaN      NaN
# 2         NaN                                   NaN       NaN      NaN
# 3         NaN                                   NaN       NaN      NaN
# 4         NaN                                   NaN       NaN      NaN
#
# [5 rows x 2186 columns]

# %%
band_columns = [str(x) for x in range(350, 999)] # list comprehension
bands = [x for x in range(350, 999)] # x values
target_bands = [x for x in range(400, 1000, 5)] # 5nm bands

# %%
for _row in speclib[band_columns].itertuples():
    row_arr = np.array(_row[1::]).flatten()
    cs = CubicSpline(bands,row_arr)
    resampled_values = cs(target_bands)
