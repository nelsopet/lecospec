# %%
if (!dir.exists("./Functions")) {
    setwd("..")
}
source("./Functions/lecospectR.R")

# %%
result_ras <- raster::raster("Output/GridSearchFullDataCubePredictionsTIF/bg_1511_Adaboost_0c878c17b798.tif")

# %%
plot_opts <- define_plot_options()

# %%
plot_categorical_raster(
    result_ras, 
    plot_options = plot_opts
)
# Out:
# plot without title

# %%
fg0_results <- change_prediction_aggregation(
    result_ras, 
    target_aggregation = 0,
    source_aggregation = 1)

# %%
png(filename = "test_pred_fg0-1.png", width=2048, height = 2048)
plot_categorical_raster(
    fg0_results, 
    plot_opts, 
    use_fg0 = TRUE)
dev.off()
# Out:
# png
#   2

# %%
svg(filename = "test_pred_fg0-3.svg")
plot_categorical_raster(
    fg0_results, 
    plot_opts, 
    use_fg0 = TRUE)
dev.off()
# Out:
# png
#   2
