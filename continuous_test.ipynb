# %%
source("./Functions/lecospectR.R")
# Out:
# Loading required package: tidyverse
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ purrr::%||%()   masks base::%||%()
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: compiler
#
# Loading required package: raster
#
# Loading required package: sp
#
#
# Attaching package: ‘raster’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# Loading required package: hsdar
#
# Loading required package: rgdal
#
# Please note that rgdal will be retired during October 2023,
# ...

# %%
input_data <- "Data/raw_0_rd_rf_56pctWhiteRef_or"

# %%
test_model <- load_model("Output/models/model_18c33e31b018d7687c2b18e8ee6f0adc.rda")

# %%
names(test_model$forest$independent.variable.names)
# Out:
# NULL

# %%
tile_path <- "tiles/tile_5bqLvp421yvtpQnq.envi"

# %%
band_names <- read.csv("assets/bands.csv")$x

# %%
tile_result <- process_tile(
    tile_path,
    ml_model = test_model,
    aggregation = 0, 
    cluster = NULL,
    save_path = "./test_cont_9may.tif", 
    return_raster = TRUE, 
    band_names = band_names, 
    raster_datatype = "FLT4S"
    )
# Out:
# [1] "preprocessing raster at tiles/tile_5bqLvp421yvtpQnq.envi"
# [1] "Converted to Data frame?"
# [1] TRUE
#   [1] "x"        "y"        "X397.593" "X399.444" "X401.296" "X403.148"
#   [7] "X405"     "X406.851" "X408.703" "X410.555" "X412.407" "X414.258"
#  [13] "X416.11"  "X417.962" "X419.814" "X421.666" "X423.517" "X425.369"
#  [19] "X427.221" "X429.073" "X430.924" "X432.776" "X434.628" "X436.48"
#  [25] "X438.332" "X440.183" "X442.035" "X443.887" "X445.739" "X447.59"
#  [31] "X449.442" "X451.294" "X453.146" "X454.998" "X456.849" "X458.701"
#  [37] "X460.553" "X462.405" "X464.256" "X466.108" "X467.96"  "X469.812"
#  [43] "X471.664" "X473.515" "X475.367" "X477.219" "X479.071" "X480.922"
#  [49] "X482.774" "X484.626" "X486.478" "X488.33"  "X490.181" "X492.033"
#  [55] "X493.885" "X495.737" "X497.588" "X499.44"  "X501.292" "X503.144"
#  [61] "X504.996" "X506.847" "X508.699" "X510.551" "X512.403" "X514.254"
#  [67] "X516.106" "X517.958" "X519.81"  "X521.662" "X523.513" "X525.365"
# ...

# %%
plot(tile_result)

# %%
raster::endCluster()

# %%
sink(NULL)

# %%
var
# Out:
# function (x, y = NULL, na.rm = FALSE, use)
# {
#     UseMethod("var")
# }
# <bytecode: 0x5be2ae027e00>
# <environment: namespace:spectrolab>

# %%
estimate_land_cover(
    input_data, 
    test_model, 
    cache_filepath = "./test-cache/",
    is_classifier = FALSE
)
# Out:
# Warning message in new_CppObject_xp(fields$.module, fields$.pointer, ...):
# "GDAL Message 1: Unrecognized datum 'WGS84', defaulting to WGS84."
# Warning message in new_CppObject_xp(fields$.module, fields$.pointer, ...):
# "GDAL Message 1: Unrecognized datum 'WGS84', defaulting to WGS84."
# Warning message in x@cpp$crop(y@cpp, snap[1], extend[1], opt):
# "GDAL Message 1: Unrecognized datum 'WGS84', defaulting to WGS84."
# Warning message in x@cpp$crop(y@cpp, snap[1], extend[1], opt):
# "GDAL Message 1: Unrecognized datum 'WGS84', defaulting to WGS84."
# Warning message in x@cpp$crop(y@cpp, snap[1], extend[1], opt):
# "GDAL Message 1: Unrecognized datum 'WGS84', defaulting to WGS84."
# Warning message in x@cpp$crop(y@cpp, snap[1], extend[1], opt):
# "GDAL Message 1: Unrecognized datum 'WGS84', defaulting to WGS84."
# Warning message in x@cpp$crop(y@cpp, snap[1], extend[1], opt):
# "GDAL Message 1: Unrecognized datum 'WGS84', defaulting to WGS84."
# ...
