# %%
setwd("C:/Users/kenne/Documents/GitHub/lecospec/")
print(getwd())
# Out:
# [1] "C:/Users/kenne/Documents/GitHub/lecospec"

# %%
# Out:
# [1] "c:/Users/kenne/Documents"

# %%
source("Functions/LandCoverEstimator_RF.R")
# Out:
# Loading required package: tidyverse
#
# Warning message:
# "package 'tidyverse' was built under R version 4.1.1"
# -- Attaching packages --------------------------------------- tidyverse 1.3.1 --
#
# v ggplot2 3.3.5     v purrr   0.3.4
# v tibble  3.1.4     v dplyr   1.0.7
# v tidyr   1.1.4     v stringr 1.4.0
# v readr   2.0.1     v forcats 0.5.1
#
# Warning message:
# "package 'ggplot2' was built under R version 4.1.1"
# Warning message:
# "package 'tibble' was built under R version 4.1.1"
# Warning message:
# "package 'tidyr' was built under R version 4.1.1"
# Warning message:
# "package 'readr' was built under R version 4.1.1"
# Warning message:
# "package 'purrr' was built under R version 4.1.1"
# Warning message:
# "package 'dplyr' was built under R version 4.1.1"
# Warning message:
# "package 'stringr' was built under R version 4.1.1"
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# ...

# %%
test_tile <-"F:/Lecospec/tiles/tile_0bYSfUorxlbPTIkA.grd"
example_raster <- raster::brick(test_tile)
example_df <- raster::rasterToPoints(example_raster)
print(colnames(example_df))
bandnames <- colnames(example_df)
bandnames <- gsub("X", "", bandnames)
bandnames <- gsub(".nm", "", bandnames)
bands <- bandnames %>% as.numeric()
bands <- bands[!is.na(bands)]

print(bands)
# Out:
#   [1] "x"           "y"           "X397.593.nm" "X399.444.nm" "X401.296.nm"
#   [6] "X403.148.nm" "X405.nm"     "X406.851.nm" "X408.703.nm" "X410.555.nm"
#  [11] "X412.407.nm" "X414.258.nm" "X416.11.nm"  "X417.962.nm" "X419.814.nm"
#  [16] "X421.666.nm" "X423.517.nm" "X425.369.nm" "X427.221.nm" "X429.073.nm"
#  [21] "X430.924.nm" "X432.776.nm" "X434.628.nm" "X436.48.nm"  "X438.332.nm"
#  [26] "X440.183.nm" "X442.035.nm" "X443.887.nm" "X445.739.nm" "X447.59.nm"
#  [31] "X449.442.nm" "X451.294.nm" "X453.146.nm" "X454.998.nm" "X456.849.nm"
#  [36] "X458.701.nm" "X460.553.nm" "X462.405.nm" "X464.256.nm" "X466.108.nm"
#  [41] "X467.96.nm"  "X469.812.nm" "X471.664.nm" "X473.515.nm" "X475.367.nm"
#  [46] "X477.219.nm" "X479.071.nm" "X480.922.nm" "X482.774.nm" "X484.626.nm"
#  [51] "X486.478.nm" "X488.33.nm"  "X490.181.nm" "X492.033.nm" "X493.885.nm"
#  [56] "X495.737.nm" "X497.588.nm" "X499.44.nm"  "X501.292.nm" "X503.144.nm"
# ...

# %%
write.csv(bands, "./Data/bands.csv")

# %%
library(caret)
library(randomForest)
library(ranger)
# Out:
# Warning message:
# "package 'randomForest' was built under R version 4.1.1"
# randomForest 4.6-14
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: 'randomForest'
#
#
# The following object is masked from 'package:ranger':
#
#     importance
#
#
# The following object is masked from 'package:spectrolab':
#
#     combine
#
#
# The following object is masked from 'package:dplyr':
#
#     combine
#
#
# The following object is masked from 'package:ggplot2':
#
#     margin

# %%
speclib_path <- "./mle/trainingData.csv"
speclib_df <- read.csv(speclib_path)

# %%
print(colnames(speclib_df))
# Out:
#   [1] "ScanID"                 "Code_name"              "Species_name"
#   [4] "Functional_group1"      "Functional_group2"      "Area"
#   [7] "Species_name_Freq"      "Functional_group1_Freq" "Functional_group2_Freq"
#  [10] "Boochs"                 "Boochs2"                "CARI"
#  [13] "Carter"                 "Carter2"                "Carter3"
#  [16] "Carter4"                "Carter5"                "Carter6"
#  [19] "CI"                     "CI2"                    "ClAInt"
#  [22] "CRI1"                   "CRI2"                   "CRI3"
#  [25] "CRI4"                   "D1"                     "D2"
#  [28] "Datt"                   "Datt2"                  "Datt3"
#  [31] "Datt4"                  "Datt5"                  "Datt6"
#  [34] "DD"                     "DDn"                    "DPI"
#  [37] "DWSI4"                  "EGFN"                   "EGFR"
#  [40] "EVI"                    "GDVI2"                  "GDVI3"
# ...

# %%
speclib <- df_to_speclib(speclib_df[,102:205])
# Out:
# [1] "Columns in band columns"
# [1] 101
# [1] "Dimensions of converted matrix"
# [1] 8001  101
# Warning message in convert_wavelength_strings(.):
# "NAs introduced by coercion"
# Warning message in convert_wavelength_strings(.):
# "NAs introduced by coercion"
# Warning message in convert_wavelength_strings(.):
# "NAs introduced by coercion"
# Warning message in convert_wavelength_strings(.):
# "NAs introduced by coercion"
# Warning message in convert_wavelength_strings(.):
# "NAs introduced by coercion"
# Warning message in convert_wavelength_strings(.):
# "NAs introduced by coercion"
# Warning message in convert_wavelength_strings(.):
# "NAs introduced by coercion"
# Warning message in convert_wavelength_strings(.):
# "NAs introduced by coercion"
# Warning message in convert_wavelength_strings(.):
# "NAs introduced by coercion"
# Warning message in convert_wavelength_strings(.):
# "NAs introduced by coercion"
# Warning message in convert_wavelength_strings(.):
# ...
